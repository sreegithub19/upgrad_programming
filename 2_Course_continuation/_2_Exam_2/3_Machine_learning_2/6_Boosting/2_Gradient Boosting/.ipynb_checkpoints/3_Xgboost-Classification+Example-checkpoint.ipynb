# %% [markdown]
# # Xgboost Classification

# %%
import numpy as np 
import pandas as pd 


import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline


from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, log_loss
from imblearn.over_sampling import SMOTE

import xgboost as xgb  # Load this xgboost

from sklearn.model_selection import train_test_split


# Import and suppress warnings
import warnings
warnings.filterwarnings('ignore')


from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, cross_val_score, learning_curve, train_test_split
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# !pip uninstall -y scikit-learn
# !pip install scikit-learn==1.3.1
# Out:
# Found existing installation: scikit-learn 1.3.1
# Uninstalling scikit-learn-1.3.1:
#   Successfully uninstalled scikit-learn-1.3.1
# Collecting scikit-learn==1.3.1
#   Using cached scikit_learn-1.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-learn==1.3.1) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-learn==1.3.1) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-learn==1.3.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-learn==1.3.1) (3.5.0)
# Using cached scikit_learn-1.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
# Installing collected packages: scikit-learn
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.3.1 which is incompatible.
# Successfully installed scikit-learn-1.3.1

# %% [markdown]
# # 1. Exploratory Data Analysis
#
# Let us load in the dataset via the trusty Pandas package into a dataframe object which we call **attrition** and have a quick look at the first few rows

# %%
attrition = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
attrition.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
# Looking for NaN
attrition.isnull().any()
# Out:
# Age                         False
# Attrition                   False
# BusinessTravel              False
# DailyRate                   False
# Department                  False
# DistanceFromHome            False
# Education                   False
# EducationField              False
# EmployeeCount               False
# EmployeeNumber              False
# EnvironmentSatisfaction     False
# Gender                      False
# HourlyRate                  False
# JobInvolvement              False
# JobLevel                    False
# JobRole                     False
# JobSatisfaction             False
# MaritalStatus               False
# MonthlyIncome               False
# MonthlyRate                 False
# NumCompaniesWorked          False
# Over18                      False
# OverTime                    False
# PercentSalaryHike           False
# PerformanceRating           False
# RelationshipSatisfaction    False
# StandardHours               False
# StockOptionLevel            False
# TotalWorkingYears           False
# TrainingTimesLastYear       False
# WorkLifeBalance             False
# YearsAtCompany              False
# YearsInCurrentRole          False
# YearsSinceLastPromotion     False
# YearsWithCurrManager        False
# dtype: bool

# %%
# attrition.Age.fillna('')

# %% [markdown]
# ### Correlation of Features

# %%
# attrition.corr()

# %% [markdown]
# #  Feature Engineering & Categorical Encoding
#
# Task of Feature engineering and numerically encoding the categorical values in our dataset.

# %%
# attrition.shape

# %%
attrition.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %%
# Empty list to store columns with categorical data
categorical = []
for col, value in attrition.items():
    if value.dtype == 'object':
        categorical.append(col)

# Store the numerical columns in a list numerical
numerical = attrition.columns.difference(categorical)

print("Categorical columns:", categorical)
print("Numerical columns:", numerical)
# Out:
# Categorical columns: ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']
# Numerical columns: Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
numerical
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
categorical
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'Over18',
#  'OverTime']

# %%
# Store the categorical data in a dataframe called attrition_cat
attrition_cat = attrition[categorical]
attrition_cat = attrition_cat.drop(['Attrition'], axis=1) # Dropping the target column

# %%
attrition_cat
# Out:
#          BusinessTravel              Department EducationField  Gender  \
# 0         Travel_Rarely                   Sales  Life Sciences  Female
# 1     Travel_Frequently  Research & Development  Life Sciences    Male
# 2         Travel_Rarely  Research & Development          Other    Male
# 3     Travel_Frequently  Research & Development  Life Sciences  Female
# 4         Travel_Rarely  Research & Development        Medical    Male
# ...                 ...                     ...            ...     ...
# 1465  Travel_Frequently  Research & Development        Medical    Male
# 1466      Travel_Rarely  Research & Development        Medical    Male
# 1467      Travel_Rarely  Research & Development  Life Sciences    Male
# 1468  Travel_Frequently                   Sales        Medical    Male
# 1469      Travel_Rarely  Research & Development        Medical    Male
#
#                         JobRole MaritalStatus Over18 OverTime
# 0               Sales Executive        Single      Y      Yes
# 1            Research Scientist       Married      Y       No
# 2         Laboratory Technician        Single      Y      Yes
# 3            Research Scientist       Married      Y      Yes
# 4         Laboratory Technician       Married      Y       No
# ...                         ...           ...    ...      ...
# 1465      Laboratory Technician       Married      Y       No
# 1466  Healthcare Representative       Married      Y       No
# 1467     Manufacturing Director       Married      Y      Yes
# 1468            Sales Executive       Married      Y       No
# 1469      Laboratory Technician       Married      Y       No
#
# [1470 rows x 8 columns]

# %% [markdown]
# Applying the **get_dummies** method

# %%
attrition_cat = pd.get_dummies(attrition_cat)
attrition_cat.head(3)
# Out:
#    BusinessTravel_Non-Travel  BusinessTravel_Travel_Frequently  \
# 0                      False                             False
# 1                      False                              True
# 2                      False                             False
#
#    BusinessTravel_Travel_Rarely  Department_Human Resources  \
# 0                          True                       False
# 1                         False                       False
# 2                          True                       False
#
#    Department_Research & Development  Department_Sales  \
# 0                              False              True
# 1                               True             False
# 2                               True             False
#
#    EducationField_Human Resources  EducationField_Life Sciences  \
# 0                           False                          True
# 1                           False                          True
# 2                           False                         False
#
#    EducationField_Marketing  EducationField_Medical  ...  \
# 0                     False                   False  ...
# 1                     False                   False  ...
# 2                     False                   False  ...
#
#    JobRole_Research Director  JobRole_Research Scientist  \
# 0                      False                       False
# 1                      False                        True
# 2                      False                       False
#
#    JobRole_Sales Executive  JobRole_Sales Representative  \
# 0                     True                         False
# 1                    False                         False
# 2                    False                         False
#
#    MaritalStatus_Divorced  MaritalStatus_Married  MaritalStatus_Single  \
# 0                   False                  False                  True
# 1                   False                   True                 False
# 2                   False                  False                  True
#
#    Over18_Y  OverTime_No  OverTime_Yes
# 0      True        False          True
# 1      True         True         False
# 2      True        False          True
#
# [3 rows x 29 columns]

# %%
# Store the numerical features to a dataframe attrition_num
attrition_num = attrition[numerical]

# %% [markdown]
# let's concat numerical and caterogial dfs

# %%
# Concat the two dataframes together columnwise
attrition_final = pd.concat([attrition_num, attrition_cat], axis=1)

# %%
attrition_final.shape
# Out:
# (1470, 55)

# %%
attrition_final.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0   41       1102                 1          2              1               1
# 1   49        279                 8          1              1               2
# 2   37       1373                 2          2              1               4
# 3   33       1392                 3          4              1               5
# 4   27        591                 2          1              1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  ...  \
# 0                        2          94               3         2  ...
# 1                        3          61               2         2  ...
# 2                        4          92               2         1  ...
# 3                        4          56               3         1  ...
# 4                        1          40               3         1  ...
#
#    JobRole_Research Director  JobRole_Research Scientist  \
# 0                      False                       False
# 1                      False                        True
# 2                      False                       False
# 3                      False                        True
# 4                      False                       False
#
#    JobRole_Sales Executive  JobRole_Sales Representative  \
# 0                     True                         False
# 1                    False                         False
# 2                    False                         False
# 3                    False                         False
# 4                    False                         False
#
#    MaritalStatus_Divorced  MaritalStatus_Married  MaritalStatus_Single  \
# 0                   False                  False                  True
# 1                   False                   True                 False
# 2                   False                  False                  True
# 3                   False                   True                 False
# 4                   False                   True                 False
#
#    Over18_Y  OverTime_No  OverTime_Yes
# 0      True        False          True
# 1      True         True         False
# 2      True        False          True
# 3      True        False          True
# 4      True         True         False
#
# [5 rows x 55 columns]

# %% [markdown]
# **Target variable**
#
# The target in this case is given by the column **Attrition** which contains categorical variables therefore requires numerical encoding. We numerically encode it by creating a dictionary with the mapping given as 1 : Yes and 0 : No

# %%
# Define a dictionary for the target mapping
target_map = {'Yes':1, 'No':0}
# Use the pandas apply method to numerically encode our attrition target variable
target = attrition["Attrition"].apply(lambda x: target_map[x])
target.head(3)
# Out:
# 0    1
# 1    0
# 2    1
# Name: Attrition, dtype: int64

# %% [markdown]
# **Splitting Data into Train and Test sets**

# %%
# Split data into train and test sets as well as for validation and testing
train, test, target_train, target_test = train_test_split(attrition_final, target, train_size= 0.75,random_state=0);

# %% [markdown]
# #  Implementing Machine Learning Models

# %% [markdown]
# ## Xgboost Classifier

# %% [markdown]
# ### 1.n_estimators - No of Trees in the Model
#
# ### 2.max_leaf_nodes = The maximum number of terminal nodes or leaves in a tree. If this is defined, max_depth will be ignored
#
# ### 3.min_child_weight - Defines the minimum sum of weights of all observations required in a child.
#
# ### 4.max_depth - Maximum Depth of Tree and can be used to control overfiting
#
# ### 5.subsample- The fraction of samples to be used for fitting the individual base learners
#
# ### 6.learning_rate - Learning rate shrinks the contribution of each tree by learning_rate. There is a trade-off between learning_rate and n_estimators
#
# ## Regularization parameters
#
# ### 7. gamma - A node is split only when the resulting split gives a postive Gain. Gamma specifies the minimum loss reduction required to make a split.
#
# ### 8. lambda - This used to handle the regularization part of XGBoost. It should be explored to reduce overfitting
#
# ## Imbalanced Data Handling
#
# ### 9. scale_pos_weight - A value greater than 0 should be used in case of high class imbalance as it helps in faster convergence

# %%
xgb_cfl = xgb.XGBClassifier(n_jobs = -1,objective = 'binary:logistic')
xgb_cfl.get_params()
# Out:
# {'objective': 'binary:logistic',
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'device': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'multi_strategy': None,
#  'n_estimators': None,
#  'n_jobs': -1,
#  'num_parallel_tree': None,
#  'random_state': None,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None}

# %%
# Fit the model to our train and target
xgb_cfl.fit(train, target_train)  # default 
# Get our predictions
xgb_predictions = xgb_cfl.predict(test)

# %%
xgb_predictions_prob = xgb_cfl.predict_proba(test)
xgb_predictions_prob
# Out:
# array([[9.80802476e-01, 1.91975068e-02],
#        [9.99925792e-01, 7.42326592e-05],
#        [9.68313873e-01, 3.16861533e-02],
#        [9.69120681e-01, 3.08792982e-02],
#        [4.23973799e-03, 9.95760262e-01],
#        [6.50538146e-01, 3.49461854e-01],
#        [7.71121085e-01, 2.28878915e-01],
#        [9.77243125e-01, 2.27568597e-02],
#        [9.96759653e-01, 3.24033108e-03],
#        [9.28561509e-01, 7.14384764e-02],
#        [9.99308348e-01, 6.91627502e-04],
#        [9.75794256e-01, 2.42057461e-02],
#        [9.99040246e-01, 9.59759229e-04],
#        [7.03077316e-02, 9.29692268e-01],
#        [9.99101222e-01, 8.98779952e-04],
#        [9.99957383e-01, 4.25999897e-05],
#        [9.95473862e-01, 4.52613644e-03],
#        [9.99491930e-01, 5.08057943e-04],
#        [9.75677967e-01, 2.43220292e-02],
#        [9.87874329e-01, 1.21256514e-02],
#        [8.60899210e-01, 1.39100775e-01],
#        [9.94047403e-01, 5.95258083e-03],
#        [9.99224126e-01, 7.75870751e-04],
#        [9.99883235e-01, 1.16776842e-04],
#        [5.05038857e-01, 4.94961172e-01],
#        [8.17822516e-01, 1.82177499e-01],
#        [9.83957827e-01, 1.60422008e-02],
#        [9.99522984e-01, 4.77034657e-04],
#        [5.22067547e-01, 4.77932483e-01],
#        [9.99577940e-01, 4.22077137e-04],
#        [9.98229086e-01, 1.77092408e-03],
#        [9.99245584e-01, 7.54439447e-04],
#        [7.52999067e-01, 2.47000933e-01],
#        [9.82552409e-01, 1.74476169e-02],
#        [9.98018801e-01, 1.98118412e-03],
#        [9.91893232e-01, 8.10675975e-03],
#        [9.11147475e-01, 8.88525024e-02],
#        [9.98436511e-01, 1.56347011e-03],
#        [9.97606575e-01, 2.39341101e-03],
#        [9.90256667e-01, 9.74333473e-03],
#        [9.73089993e-01, 2.69099884e-02],
#        [9.99100387e-01, 8.99637584e-04],
#        [9.97892439e-01, 2.10755155e-03],
#        [9.93044734e-01, 6.95525995e-03],
#        [9.98967230e-01, 1.03276072e-03],
#        [1.33982062e-01, 8.66017938e-01],
#        [9.91763532e-01, 8.23649112e-03],
#        [9.43483949e-01, 5.65160289e-02],
#        [9.98031318e-01, 1.96870649e-03],
#        [6.00231647e-01, 3.99768353e-01],
#        [9.99686003e-01, 3.14015866e-04],
#        [2.42450774e-01, 7.57549226e-01],
#        [9.96653616e-01, 3.34635773e-03],
#        [9.67198968e-01, 3.28010395e-02],
#        [9.79819238e-01, 2.01807786e-02],
#        [9.86936033e-01, 1.30639896e-02],
#        [9.99398947e-01, 6.01058069e-04],
#        [7.18984842e-01, 2.81015158e-01],
#        [9.37154531e-01, 6.28454909e-02],
#        [9.99307573e-01, 6.92419300e-04],
#        [9.98674631e-01, 1.32538343e-03],
#        [9.99401212e-01, 5.98776911e-04],
#        [9.70353782e-01, 2.96462402e-02],
#        [9.81060326e-01, 1.89396739e-02],
#        [6.72190785e-01, 3.27809215e-01],
#        [6.93983436e-01, 3.06016535e-01],
#        [8.79644394e-01, 1.20355628e-01],
#        [9.77852821e-01, 2.21471712e-02],
#        [9.99825299e-01, 1.74718502e-04],
#        [9.99593616e-01, 4.06398554e-04],
#        [9.96278822e-01, 3.72117269e-03],
#        [9.77262914e-01, 2.27371119e-02],
#        [1.24838650e-01, 8.75161350e-01],
#        [9.99710500e-01, 2.89500167e-04],
#        [9.98852491e-01, 1.14750920e-03],
#        [9.89940524e-01, 1.00594554e-02],
#        [9.98486757e-01, 1.51326624e-03],
#        [9.98516202e-01, 1.48382271e-03],
#        [9.69671190e-01, 3.03288121e-02],
#        [9.99492109e-01, 5.07882214e-04],
#        [9.21956778e-01, 7.80432150e-02],
#        [9.99742150e-01, 2.57871638e-04],
#        [9.83225346e-01, 1.67746730e-02],
#        [9.84580517e-01, 1.54194990e-02],
#        [9.74699438e-01, 2.53005736e-02],
#        [9.71273541e-01, 2.87264753e-02],
#        [9.99769390e-01, 2.30598816e-04],
#        [9.98335838e-01, 1.66417542e-03],
#        [9.97881234e-01, 2.11877306e-03],
#        [9.92624521e-01, 7.37547502e-03],
#        [8.79739165e-01, 1.20260850e-01],
#        [9.99703646e-01, 2.96334591e-04],
#        [9.91127014e-01, 8.87296908e-03],
#        [9.90942001e-01, 9.05802846e-03],
#        [9.98413026e-01, 1.58697122e-03],
#        [9.98014212e-01, 1.98576506e-03],
#        [9.79971588e-01, 2.00283956e-02],
#        [9.98187900e-01, 1.81208248e-03],
#        [9.06010032e-01, 9.39899385e-02]], dtype=float32)

# %%
accuracy_score(target_test, xgb_predictions)
# Out:
# 0.8695652173913043

# %% [markdown]
# # HPT - Random Search

# %%
# A parameter grid for XGBoost
params = {
        'n_estimators' : [100, 200, 500, 750], # no of trees 
        'learning_rate' : [0.01, 0.02, 0.05, 0.1, 0.25],  # eta
        'min_child_weight': [1, 5, 7, 10],
        'gamma': [0.1, 0.5, 1, 1.5, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5, 10, 12]
        }

folds = 5

param_comb = 800

random_search = RandomizedSearchCV(xgb_cfl, param_distributions=params, n_iter=param_comb, scoring='accuracy', n_jobs=-1, cv=5, verbose=3, random_state=42)

# %%
random_search.fit(train, target_train)
# Out:
# Fitting 5 folds for each of 800 candidates, totalling 4000 fits
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.864 total time=   1.3s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.877 total time=   1.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.859 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.02, max_depth=4, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.855 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.02, max_depth=4, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.873 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.02, max_depth=4, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.850 total time=   1.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=4, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.850 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=4, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.895 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=500, subsample=1.0;, score=0.860 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=500, subsample=1.0;, score=0.850 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=500, subsample=1.0;, score=0.859 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.873 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.877 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.25, max_depth=3, min_child_weight=1, n_estimators=750, subsample=0.8;, score=0.873 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.25, max_depth=3, min_child_weight=1, n_estimators=750, subsample=0.8;, score=0.859 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=200, subsample=0.8;, score=0.851 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=200, subsample=0.8;, score=0.878 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=200, subsample=0.8;, score=0.886 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=4, min_child_weight=7, n_estimators=100, subsample=0.8;, score=0.842 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=4, min_child_weight=7, n_estimators=100, subsample=0.8;, score=0.841 total time=   0.6s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=4, min_child_weight=7, n_estimators=100, subsample=0.8;, score=0.841 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.05, max_depth=12, min_child_weight=7, n_estimators=200, subsample=0.6;, score=0.864 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.05, max_depth=12, min_child_weight=7, n_estimators=200, subsample=0.6;, score=0.873 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.1, max_depth=4, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.860 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.1, max_depth=4, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.882 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=5, learning_rate=0.02, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.860 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=5, learning_rate=0.02, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.850 total time=   0.3s
# [CV 5/5] END colsample_bytree=1.0, gamma=5, learning_rate=0.02, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.845 total time=   0.6s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.25, max_depth=3, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.882 total time=   0.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.25, max_depth=3, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.882 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.8;, score=0.869 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.8;, score=0.859 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.8;, score=0.864 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.02, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.6;, score=0.873 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.02, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.6;, score=0.868 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=12, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.864 total time=   1.2s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=12, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.873 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.855 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.860 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.882 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.02, max_depth=5, min_child_weight=10, n_estimators=750, subsample=1.0;, score=0.864 total time=   1.9s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.02, max_depth=5, min_child_weight=10, n_estimators=750, subsample=1.0;, score=0.873 total time=   2.0s
# [CV 1/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.25, max_depth=5, min_child_weight=10, n_estimators=100, subsample=1.0;, score=0.860 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.25, max_depth=5, min_child_weight=10, n_estimators=100, subsample=1.0;, score=0.864 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.25, max_depth=5, min_child_weight=10, n_estimators=100, subsample=1.0;, score=0.855 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.25, max_depth=5, min_child_weight=10, n_estimators=100, subsample=1.0;, score=0.864 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.25, max_depth=5, min_child_weight=10, n_estimators=100, subsample=1.0;, score=0.864 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.846 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.841 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.05, max_depth=12, min_child_weight=10, n_estimators=200, subsample=0.8;, score=0.855 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.864 total time=   1.4s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.873 total time=   1.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.02, max_depth=4, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.860 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.02, max_depth=4, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.841 total time=   1.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=4, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.837 total time=   0.9s
# [CV 2/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=4, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.878 total time=   1.1s
# [CV 4/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=4, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.877 total time=   1.2s
# [CV 1/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=500, subsample=1.0;, score=0.855 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=500, subsample=1.0;, score=0.850 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.860 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.864 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.882 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.25, max_depth=3, min_child_weight=1, n_estimators=750, subsample=0.8;, score=0.855 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.25, max_depth=3, min_child_weight=1, n_estimators=750, subsample=0.8;, score=0.864 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.25, max_depth=3, min_child_weight=1, n_estimators=750, subsample=0.8;, score=0.873 total time=   1.1s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=200, subsample=0.8;, score=0.873 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=200, subsample=0.8;, score=0.877 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=4, min_child_weight=7, n_estimators=100, subsample=0.8;, score=0.837 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=4, min_child_weight=7, n_estimators=100, subsample=0.8;, score=0.836 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.05, max_depth=12, min_child_weight=7, n_estimators=200, subsample=0.6;, score=0.864 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.05, max_depth=12, min_child_weight=7, n_estimators=200, subsample=0.6;, score=0.864 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.05, max_depth=12, min_child_weight=7, n_estimators=200, subsample=0.6;, score=0.859 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.1, max_depth=4, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.864 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.1, max_depth=4, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.873 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.1, max_depth=4, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.864 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=5, learning_rate=0.02, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.851 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=5, learning_rate=0.02, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.845 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.25, max_depth=3, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.860 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.25, max_depth=3, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.873 total time=   0.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.25, max_depth=3, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.886 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.8;, score=0.855 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.8;, score=0.864 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.02, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.6;, score=0.860 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.02, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.6;, score=0.850 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.02, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.6;, score=0.873 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=12, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.864 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=12, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.877 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=12, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.859 total time=   0.9s
# [CV 3/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.873 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.868 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.02, max_depth=5, min_child_weight=10, n_estimators=750, subsample=1.0;, score=0.846 total time=   1.7s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.02, max_depth=5, min_child_weight=10, n_estimators=750, subsample=1.0;, score=0.864 total time=   1.9s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.02, max_depth=5, min_child_weight=10, n_estimators=750, subsample=1.0;, score=0.891 total time=   1.8s
# [CV 1/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.846 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.850 total time=   0.6s
# [CV 5/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.850 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.05, max_depth=12, min_child_weight=10, n_estimators=200, subsample=0.8;, score=0.873 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.05, max_depth=12, min_child_weight=10, n_estimators=200, subsample=0.8;, score=0.873 total time=   0.8s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.02, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.6;, score=0.869 total time=   1.0s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.02, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.6;, score=0.877 total time=   1.2s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.02, max_depth=12, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.855 total time=   1.6s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.02, max_depth=12, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.855 total time=   1.3s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.02, max_depth=12, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.882 total time=   1.1s
# [CV 3/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=200, subsample=0.6;, score=0.845 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=200, subsample=0.6;, score=0.850 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.05, max_depth=12, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.882 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.05, max_depth=12, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.859 total time=   0.6s
# [CV 5/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.05, max_depth=12, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.891 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.25, max_depth=5, min_child_weight=1, n_estimators=750, subsample=0.8;, score=0.842 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.25, max_depth=5, min_child_weight=1, n_estimators=750, subsample=0.8;, score=0.868 total time=   1.1s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.25, max_depth=5, min_child_weight=1, n_estimators=750, subsample=0.8;, score=0.864 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.873 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.877 total time=   0.6s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.842 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.836 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=5, learning_rate=0.25, max_depth=10, min_child_weight=7, n_estimators=100, subsample=0.6;, score=0.869 total time=   0.3s
# [CV 3/5] END colsample_bytree=1.0, gamma=5, learning_rate=0.25, max_depth=10, min_child_weight=7, n_estimators=100, subsample=0.6;, score=0.864 total time=   0.3s
# [CV 5/5] END colsample_bytree=1.0, gamma=5, learning_rate=0.25, max_depth=10, min_child_weight=7, n_estimators=100, subsample=0.6;, score=0.873 total time=   0.3s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=500, subsample=1.0;, score=0.878 total time=   1.7s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=500, subsample=1.0;, score=0.886 total time=   1.2s
# [CV 1/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.02, max_depth=12, min_child_weight=7, n_estimators=200, subsample=0.8;, score=0.860 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.02, max_depth=12, min_child_weight=7, n_estimators=200, subsample=0.8;, score=0.869 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.02, max_depth=12, min_child_weight=7, n_estimators=200, subsample=0.8;, score=0.864 total time=   0.6s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.02, max_depth=12, min_child_weight=7, n_estimators=200, subsample=0.8;, score=0.859 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=750, subsample=0.8;, score=0.869 total time=   1.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=750, subsample=0.8;, score=0.877 total time=   1.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.25, max_depth=10, min_child_weight=7, n_estimators=500, subsample=1.0;, score=0.864 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.25, max_depth=10, min_child_weight=7, n_estimators=500, subsample=1.0;, score=0.864 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.25, max_depth=10, min_child_weight=7, n_estimators=500, subsample=1.0;, score=0.877 total time=   0.9s
# [CV 2/5] END colsample_bytree=1.0, gamma=1.5, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=750, subsample=1.0;, score=0.864 total time=   1.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=1.5, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=750, subsample=1.0;, score=0.877 total time=   1.0s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.860 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.860 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.877 total time=   0.6s
# [CV 1/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.833 total time=   1.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.859 total time=   1.2s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.855 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=750, subsample=0.6;, score=0.878 total time=   1.6s
# [CV 4/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=750, subsample=0.6;, score=0.882 total time=   1.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.869 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.869 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.864 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.882 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.891 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.02, max_depth=12, min_child_weight=5, n_estimators=750, subsample=0.6;, score=0.846 total time=   1.9s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.02, max_depth=12, min_child_weight=5, n_estimators=750, subsample=0.6;, score=0.886 total time=   1.6s
# [CV 1/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.855 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.859 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.882 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=12, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.864 total time=   1.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.05, max_depth=12, min_child_weight=10, n_estimators=200, subsample=0.8;, score=0.859 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.05, max_depth=12, min_child_weight=10, n_estimators=200, subsample=0.8;, score=0.877 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.02, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.6;, score=0.869 total time=   1.1s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.02, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.6;, score=0.868 total time=   0.9s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.02, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.6;, score=0.868 total time=   1.0s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.02, max_depth=12, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.878 total time=   1.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.02, max_depth=12, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.886 total time=   1.3s
# [CV 1/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=200, subsample=0.6;, score=0.851 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=200, subsample=0.6;, score=0.851 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=200, subsample=0.6;, score=0.845 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.05, max_depth=12, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.851 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.05, max_depth=12, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.882 total time=   0.9s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.25, max_depth=5, min_child_weight=1, n_estimators=750, subsample=0.8;, score=0.869 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.25, max_depth=5, min_child_weight=1, n_estimators=750, subsample=0.8;, score=0.877 total time=   0.9s
# [CV 1/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.864 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.873 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.882 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.846 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.841 total time=   0.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.841 total time=   0.2s
# [CV 2/5] END colsample_bytree=1.0, gamma=5, learning_rate=0.25, max_depth=10, min_child_weight=7, n_estimators=100, subsample=0.6;, score=0.873 total time=   0.3s
# [CV 4/5] END colsample_bytree=1.0, gamma=5, learning_rate=0.25, max_depth=10, min_child_weight=7, n_estimators=100, subsample=0.6;, score=0.868 total time=   0.3s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=500, subsample=1.0;, score=0.851 total time=   1.7s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=500, subsample=1.0;, score=0.855 total time=   1.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=500, subsample=1.0;, score=0.864 total time=   1.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.02, max_depth=12, min_child_weight=7, n_estimators=200, subsample=0.8;, score=0.882 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=750, subsample=0.8;, score=0.855 total time=   1.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=750, subsample=0.8;, score=0.836 total time=   1.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=750, subsample=0.8;, score=0.868 total time=   1.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.25, max_depth=10, min_child_weight=7, n_estimators=500, subsample=1.0;, score=0.855 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.25, max_depth=10, min_child_weight=7, n_estimators=500, subsample=1.0;, score=0.882 total time=   0.8s
# [CV 1/5] END colsample_bytree=1.0, gamma=1.5, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=750, subsample=1.0;, score=0.860 total time=   1.0s
# [CV 3/5] END colsample_bytree=1.0, gamma=1.5, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=750, subsample=1.0;, score=0.850 total time=   1.3s
# [CV 5/5] END colsample_bytree=1.0, gamma=1.5, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=750, subsample=1.0;, score=0.864 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.841 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.850 total time=   0.9s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.864 total time=   1.2s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.873 total time=   1.1s
# [CV 1/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=750, subsample=0.6;, score=0.860 total time=   1.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=750, subsample=0.6;, score=0.859 total time=   1.6s
# [CV 5/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=750, subsample=0.6;, score=0.868 total time=   2.0s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.02, max_depth=12, min_child_weight=5, n_estimators=750, subsample=0.6;, score=0.882 total time=   1.8s
# [CV 3/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.02, max_depth=12, min_child_weight=5, n_estimators=750, subsample=0.6;, score=0.850 total time=   1.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.02, max_depth=12, min_child_weight=5, n_estimators=750, subsample=0.6;, score=0.873 total time=   0.9s
# [CV 2/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.882 total time=   0.9s
# [CV 4/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.891 total time=   1.2s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=12, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.864 total time=   1.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=12, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.868 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=12, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.859 total time=   1.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=200, subsample=0.6;, score=0.873 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=200, subsample=0.6;, score=0.873 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=200, subsample=0.6;, score=0.868 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.864 total time=   1.6s
# [CV 4/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.868 total time=   1.6s
# [CV 1/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.6;, score=0.842 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.6;, score=0.837 total time=   0.6s
# [CV 3/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.6;, score=0.841 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.6;, score=0.845 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.878 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.873 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=750, subsample=1.0;, score=0.855 total time=   1.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=750, subsample=1.0;, score=0.882 total time=   1.3s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=100, subsample=0.8;, score=0.842 total time=   0.9s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=100, subsample=0.8;, score=0.841 total time=   1.0s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=100, subsample=0.8;, score=0.836 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.1, max_depth=4, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.860 total time=   1.2s
# [CV 4/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.1, max_depth=4, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.900 total time=   1.1s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.02, max_depth=4, min_child_weight=7, n_estimators=100, subsample=0.8;, score=0.842 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.02, max_depth=4, min_child_weight=7, n_estimators=100, subsample=0.8;, score=0.850 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.02, max_depth=4, min_child_weight=7, n_estimators=100, subsample=0.8;, score=0.855 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.882 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.886 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=750, subsample=1.0;, score=0.860 total time=   2.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=750, subsample=1.0;, score=0.859 total time=   2.1s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=750, subsample=1.0;, score=0.864 total time=   1.9s
# [CV 3/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.25, max_depth=3, min_child_weight=10, n_estimators=200, subsample=0.8;, score=0.873 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.25, max_depth=3, min_child_weight=10, n_estimators=200, subsample=0.8;, score=0.845 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.02, max_depth=10, min_child_weight=10, n_estimators=200, subsample=0.8;, score=0.860 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.02, max_depth=10, min_child_weight=10, n_estimators=200, subsample=0.8;, score=0.877 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.02, max_depth=10, min_child_weight=10, n_estimators=200, subsample=0.8;, score=0.855 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.05, max_depth=12, min_child_weight=7, n_estimators=750, subsample=0.6;, score=0.882 total time=   1.2s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.05, max_depth=12, min_child_weight=7, n_estimators=750, subsample=0.6;, score=0.891 total time=   1.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=500, subsample=0.8;, score=0.864 total time=   1.2s
# [CV 2/5] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=500, subsample=0.8;, score=0.864 total time=   1.0s
# [CV 4/5] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=500, subsample=0.8;, score=0.873 total time=   0.9s
# [CV 1/5] END colsample_bytree=1.0, gamma=1.5, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, subsample=0.8;, score=0.860 total time=   2.0s
# [CV 3/5] END colsample_bytree=1.0, gamma=1.5, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, subsample=0.8;, score=0.850 total time=   1.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=1.5, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, subsample=0.8;, score=0.877 total time=   1.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.6;, score=0.864 total time=   0.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.6;, score=0.886 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=3, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.860 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=3, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.868 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=3, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.877 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.887 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.886 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.25, max_depth=5, min_child_weight=7, n_estimators=500, subsample=0.8;, score=0.828 total time=   1.1s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.25, max_depth=5, min_child_weight=7, n_estimators=500, subsample=0.8;, score=0.836 total time=   0.9s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.25, max_depth=5, min_child_weight=7, n_estimators=500, subsample=0.8;, score=0.859 total time=   0.8s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.869 total time=   1.9s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=12, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.873 total time=   1.3s
# [CV 1/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=200, subsample=0.6;, score=0.864 total time=   0.9s
# [CV 3/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=200, subsample=0.6;, score=0.868 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.855 total time=   1.5s
# [CV 3/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.859 total time=   1.6s
# [CV 5/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.868 total time=   1.6s
# [CV 4/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.6;, score=0.841 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.864 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.864 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.868 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=750, subsample=1.0;, score=0.873 total time=   0.9s
# [CV 3/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=750, subsample=1.0;, score=0.855 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=750, subsample=1.0;, score=0.868 total time=   1.1s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=100, subsample=0.8;, score=0.837 total time=   1.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=10, min_child_weight=7, n_estimators=100, subsample=0.8;, score=0.841 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.1, max_depth=4, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.882 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.1, max_depth=4, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.859 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.1, max_depth=4, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.877 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.02, max_depth=4, min_child_weight=7, n_estimators=100, subsample=0.8;, score=0.864 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.02, max_depth=4, min_child_weight=7, n_estimators=100, subsample=0.8;, score=0.845 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.837 total time=   0.6s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.855 total time=   0.6s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.873 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=750, subsample=1.0;, score=0.873 total time=   2.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=10, min_child_weight=10, n_estimators=750, subsample=1.0;, score=0.877 total time=   2.8s
# [CV 1/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.25, max_depth=3, min_child_weight=10, n_estimators=200, subsample=0.8;, score=0.869 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.25, max_depth=3, min_child_weight=10, n_estimators=200, subsample=0.8;, score=0.882 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.25, max_depth=3, min_child_weight=10, n_estimators=200, subsample=0.8;, score=0.877 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.02, max_depth=10, min_child_weight=10, n_estimators=200, subsample=0.8;, score=0.860 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.02, max_depth=10, min_child_weight=10, n_estimators=200, subsample=0.8;, score=0.873 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.05, max_depth=12, min_child_weight=7, n_estimators=750, subsample=0.6;, score=0.846 total time=   1.2s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.05, max_depth=12, min_child_weight=7, n_estimators=750, subsample=0.6;, score=0.850 total time=   1.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.05, max_depth=12, min_child_weight=7, n_estimators=750, subsample=0.6;, score=0.891 total time=   2.3s
# [CV 3/5] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=500, subsample=0.8;, score=0.868 total time=   1.0s
# [CV 5/5] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=500, subsample=0.8;, score=0.868 total time=   1.2s
# [CV 2/5] END colsample_bytree=1.0, gamma=1.5, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, subsample=0.8;, score=0.873 total time=   1.9s
# [CV 4/5] END colsample_bytree=1.0, gamma=1.5, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, subsample=0.8;, score=0.873 total time=   1.9s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.6;, score=0.860 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.6;, score=0.850 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.6;, score=0.877 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=3, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.864 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=3, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.882 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.855 total time=   0.6s
# ...
# [CV 2/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.873 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.8, gamma=5, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.859 total time=   0.2s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.02, max_depth=3, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.860 total time=   0.2s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.02, max_depth=3, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.864 total time=   0.2s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.02, max_depth=3, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.864 total time=   0.2s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.05, max_depth=10, min_child_weight=10, n_estimators=750, subsample=1.0;, score=0.873 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.05, max_depth=10, min_child_weight=10, n_estimators=750, subsample=1.0;, score=0.877 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.860 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.868 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.864 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=200, subsample=0.8;, score=0.851 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=200, subsample=0.8;, score=0.845 total time=   0.2s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.01, max_depth=5, min_child_weight=10, n_estimators=200, subsample=0.6;, score=0.851 total time=   0.2s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.01, max_depth=5, min_child_weight=10, n_estimators=200, subsample=0.6;, score=0.845 total time=   0.2s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.01, max_depth=5, min_child_weight=10, n_estimators=200, subsample=0.6;, score=0.850 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=12, min_child_weight=7, n_estimators=750, subsample=0.8;, score=0.873 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=12, min_child_weight=7, n_estimators=750, subsample=0.8;, score=0.886 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.05, max_depth=12, min_child_weight=7, n_estimators=100, subsample=0.6;, score=0.873 total time=   0.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.05, max_depth=12, min_child_weight=7, n_estimators=100, subsample=0.6;, score=0.869 total time=   0.1s
# [CV 3/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.05, max_depth=12, min_child_weight=7, n_estimators=100, subsample=0.6;, score=0.859 total time=   0.1s
# [CV 4/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.05, max_depth=12, min_child_weight=7, n_estimators=100, subsample=0.6;, score=0.868 total time=   0.1s
# [CV 5/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.05, max_depth=12, min_child_weight=7, n_estimators=100, subsample=0.6;, score=0.868 total time=   0.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.25, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.860 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.25, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.882 total time=   0.2s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.01, max_depth=12, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.851 total time=   0.2s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.01, max_depth=12, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.850 total time=   0.2s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.01, max_depth=12, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.864 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.25, max_depth=12, min_child_weight=1, n_estimators=200, subsample=0.6;, score=0.864 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.25, max_depth=12, min_child_weight=1, n_estimators=200, subsample=0.6;, score=0.891 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=10, min_child_weight=10, n_estimators=750, subsample=0.8;, score=0.851 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=10, min_child_weight=10, n_estimators=750, subsample=0.8;, score=0.850 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=10, min_child_weight=10, n_estimators=750, subsample=0.8;, score=0.882 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=12, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.873 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.1, max_depth=5, min_child_weight=7, n_estimators=750, subsample=1.0;, score=0.851 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.1, max_depth=5, min_child_weight=7, n_estimators=750, subsample=1.0;, score=0.855 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.1, max_depth=5, min_child_weight=7, n_estimators=750, subsample=1.0;, score=0.877 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.05, max_depth=5, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.869 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.05, max_depth=5, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.895 total time=   0.3s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.01, max_depth=5, min_child_weight=10, n_estimators=200, subsample=0.6;, score=0.845 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=12, min_child_weight=7, n_estimators=750, subsample=0.8;, score=0.864 total time=   0.6s
# [CV 3/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=12, min_child_weight=7, n_estimators=750, subsample=0.8;, score=0.859 total time=   0.6s
# [CV 5/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=12, min_child_weight=7, n_estimators=750, subsample=0.8;, score=0.868 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.25, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.851 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.25, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.859 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=5, learning_rate=0.25, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.877 total time=   0.2s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.01, max_depth=12, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.855 total time=   0.2s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.01, max_depth=12, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.845 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.25, max_depth=12, min_child_weight=1, n_estimators=200, subsample=0.6;, score=0.860 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.25, max_depth=12, min_child_weight=1, n_estimators=200, subsample=0.6;, score=0.827 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.25, max_depth=12, min_child_weight=1, n_estimators=200, subsample=0.6;, score=0.855 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=10, min_child_weight=10, n_estimators=750, subsample=0.8;, score=0.887 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=10, min_child_weight=10, n_estimators=750, subsample=0.8;, score=0.886 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=12, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.860 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=12, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.846 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=12, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.836 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=12, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.836 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.1, max_depth=5, min_child_weight=7, n_estimators=750, subsample=1.0;, score=0.878 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.1, max_depth=5, min_child_weight=7, n_estimators=750, subsample=1.0;, score=0.882 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.05, max_depth=5, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.837 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.05, max_depth=5, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.850 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.05, max_depth=5, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.873 total time=   0.3s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=4, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.887 total time=   0.3s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=4, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.886 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.25, max_depth=10, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.851 total time=   0.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.25, max_depth=10, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.882 total time=   0.1s
# [CV 3/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.25, max_depth=10, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.868 total time=   0.1s
# [CV 4/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.25, max_depth=10, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.882 total time=   0.1s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.8;, score=0.855 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, subsample=0.8;, score=0.855 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.860 total time=   0.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.869 total time=   0.1s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.877 total time=   0.1s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.877 total time=   0.1s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.02, max_depth=4, min_child_weight=5, n_estimators=750, subsample=0.8;, score=0.891 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.02, max_depth=4, min_child_weight=5, n_estimators=750, subsample=0.8;, score=0.886 total time=   0.7s
# [CV 1/5] END colsample_bytree=1.0, gamma=1.5, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.860 total time=   0.1s
# [CV 2/5] END colsample_bytree=1.0, gamma=1.5, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.864 total time=   0.1s
# [CV 3/5] END colsample_bytree=1.0, gamma=1.5, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.868 total time=   0.1s
# [CV 4/5] END colsample_bytree=1.0, gamma=1.5, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.873 total time=   0.1s
# [CV 1/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.01, max_depth=12, min_child_weight=5, n_estimators=750, subsample=0.6;, score=0.864 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.01, max_depth=12, min_child_weight=5, n_estimators=750, subsample=0.6;, score=0.859 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.01, max_depth=12, min_child_weight=5, n_estimators=750, subsample=0.6;, score=0.868 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=750, subsample=0.8;, score=0.873 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=750, subsample=0.8;, score=0.882 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.6;, score=0.864 total time=   0.3s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.6;, score=0.841 total time=   0.3s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=200, subsample=0.6;, score=0.864 total time=   0.3s
# RandomizedSearchCV(cv=5,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate...
#                                            num_parallel_tree=None,
#                                            random_state=None, ...),
#                    n_iter=800, n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.6, 0.8, 1.0],
#                                         'gamma': [0.1, 0.5, 1, 1.5, 5],
#                                         'learning_rate': [0.01, 0.02, 0.05, 0.1,
#                                                           0.25],
#                                         'max_depth': [3, 4, 5, 10, 12],
#                                         'min_child_weight': [1, 5, 7, 10],
#                                         'n_estimators': [100, 200, 500, 750],
#                                         'subsample': [0.6, 0.8, 1.0]},
#                    random_state=42, scoring='accuracy', verbose=3)

# %%
print('\n Best estimator:')
print(random_search.best_estimator_)
print('\n Best accuracy for %d-fold search with %d parameter combinations:' % (folds, param_comb))
print(random_search.best_score_ )
print('\n Best hyperparameters:')
print(random_search.best_params_)
# Out:
#  Best estimator:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.6, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=1.5, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=7, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=-1,
#               num_parallel_tree=None, random_state=None, ...)
#
#  Best accuracy for 5-fold search with 800 parameter combinations:
# 0.8793253805018513
#
#  Best hyperparameters:
# {'subsample': 0.8, 'n_estimators': 500, 'min_child_weight': 7, 'max_depth': 5, 'learning_rate': 0.1, 'gamma': 1.5, 'colsample_bytree': 0.6}

# %%
xgb_predictions_hpt = random_search.predict(test)
accuracy_score(target_test, xgb_predictions_hpt)
# Out:
# 0.8831521739130435

# %% [markdown]
# #### Score here shows that HPT helped improving the Model accuracy

# %% [markdown]
# ### Feature Importance Xgboost Model

# %%
xgb_cfl.feature_importances_
# Out:
# array([0.02663871, 0.01600106, 0.01433308, 0.01167052, 0.        ,
#        0.01372479, 0.02261208, 0.01608823, 0.02286761, 0.0503764 ,
#        0.02042658, 0.02043496, 0.01375093, 0.02660762, 0.01451358,
#        0.        , 0.01975274, 0.        , 0.02983482, 0.01363983,
#        0.01295772, 0.01620325, 0.0169708 , 0.01497729, 0.01723427,
#        0.04283749, 0.00261417, 0.03125522, 0.05138135, 0.        ,
#        0.01664683, 0.01017353, 0.        , 0.01151736, 0.01584176,
#        0.01469793, 0.        , 0.01378211, 0.01465011, 0.        ,
#        0.        , 0.        , 0.0163368 , 0.03206247, 0.0894463 ,
#        0.        , 0.01567406, 0.03245819, 0.01162295, 0.02320496,
#        0.01343417, 0.0640484 , 0.        , 0.04469697, 0.        ],
#       dtype=float32)

# %%
# Scatter plot 
trace = go.Scatter(
    y = xgb_cfl.feature_importances_,
    x = attrition_final.columns.values,
    mode='markers',
    marker=dict(
        sizemode = 'diameter',
        sizeref = 1.3,
        size = 12,
        color = xgb_cfl.feature_importances_,
        colorscale='Portland',
        showscale=True
    ),
    text = attrition_final.columns.values
)
data = [trace]

layout= go.Layout(
    autosize= True,
    title= 'XGBOOST Model Feature Importance',
    hovermode= 'closest',
     xaxis= dict(
         ticklen= 5,
         showgrid=False,
        zeroline=False,
        showline=False
     ),
    yaxis=dict(
        title= 'Feature Importance',
        showgrid=False,
        zeroline=False,
        ticklen= 5,
        gridwidth= 2
    ),
    showlegend= False
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig,filename='scatter')
