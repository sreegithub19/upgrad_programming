# %%
# Importing the required libraries
import pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline

# %%
# Reading the csv file and putting it into 'df' object.
df = pd.read_csv('heart_v2.csv')

# %%
df.columns
# Out:
# Index(['age', 'sex', 'BP', 'cholestrol', 'heart disease'], dtype='object')

# %%
df.head()
# Out:
#    age  sex   BP  cholestrol  heart disease
# 0   70    1  130         322              1
# 1   67    0  115         564              0
# 2   57    1  124         261              1
# 3   64    1  128         263              0
# 4   74    0  120         269              0

# %%
# Putting feature variable to X
X = df.drop('heart disease',axis=1)

# Putting response variable to y
y = df['heart disease']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((189, 4), (81, 4))

# %% [markdown]
# Fitting the decision tree with default hyperparameters, apart from max_depth which is 3 so that we can plot and read the tree.

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(max_depth=3)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
# !pip install six pydotplus graphviz
# !conda install -y graphviz
# Out:
# Requirement already satisfied: six in /home/codespace/.local/lib/python3.12/site-packages (1.17.0)
# Requirement already satisfied: pydotplus in /usr/local/python/3.12.1/lib/python3.12/site-packages (2.0.2)
# Requirement already satisfied: graphviz in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.20.3)
# Requirement already satisfied: pyparsing>=2.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from pydotplus) (3.2.0)
# /opt/conda/lib/python3.12/site-packages/conda/base/context.py:201: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# /opt/conda/lib/python3.12/site-packages/conda/base/context.py:201: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# Channels:
#  - defaults
# Platform: linux-64
# doneecting package metadata (repodata.json): -
# doneing environment: /
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - graphviz
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     atk-1.0-2.36.0             |       ha1a6a79_0         466 KB
#     boost-cpp-1.82.0           |       hdb19cb5_2          11 KB
#     ca-certificates-2024.12.31 |       h06a4308_0         128 KB
#     cairo-1.16.0               |       hb05425b_5         1.2 MB
#     certifi-2024.12.14         |  py312h06a4308_0         161 KB
#     conda-25.1.0               |  py312h06a4308_0         1.2 MB
#     conda-libmamba-solver-25.1.1|     pyhd3eb1b0_0          39 KB
#     cpp-expected-1.1.0         |       hdb19cb5_0         130 KB
#     expat-2.6.4                |       h6a678d5_0         180 KB
#     font-ttf-dejavu-sans-mono-2.37|       hd3eb1b0_0         335 KB
#     font-ttf-inconsolata-2.001 |       hcb22688_0          83 KB
#     font-ttf-source-code-pro-2.030|       hd3eb1b0_0         654 KB
#     font-ttf-ubuntu-0.83       |       h8b1ccd4_0         1.5 MB
#     fontconfig-2.14.1          |       h55d465d_3         281 KB
#     fonts-anaconda-1           |       h8fa9717_0           3 KB
#     fonts-conda-ecosystem-1    |       hd3eb1b0_0           5 KB
#     freetype-2.12.1            |       h4a9f257_0         626 KB
#     fribidi-1.0.10             |       h7b6447c_0         103 KB
#     gdk-pixbuf-2.42.10         |       h5eee18b_1         602 KB
#     giflib-5.2.2               |       h5eee18b_0          80 KB
#     glib-2.78.4                |       h6a678d5_0         508 KB
#     glib-tools-2.78.4          |       h6a678d5_0         115 KB
#     gobject-introspection-1.78.1|  py312h42194e9_2         1.7 MB
#     graphite2-1.3.14           |       h295c915_1          97 KB
#     graphviz-2.50.0            |       h78213b7_2         2.6 MB
#     gtk2-2.24.33               |       h73c1081_2         3.3 MB
#     gts-0.7.6                  |       hb67d8dd_3         310 KB
#     harfbuzz-4.3.0             |       hf52aaf7_2         1.3 MB
#     jpeg-9e                    |       h5eee18b_3         262 KB
#     lcms2-2.16                 |       hb9589c4_0         269 KB
#     lerc-4.0.0                 |       h6a678d5_0         261 KB
#     libarchive-3.7.7           |       hfab0078_0         936 KB
#     libboost-1.82.0            |       h109eef0_2        19.5 MB
#     libdeflate-1.22            |       h5eee18b_0          68 KB
#     libgd-2.3.3                |       h6a678d5_3         239 KB
#     libglib-2.78.4             |       hdc74915_0         1.5 MB
#     libiconv-1.16              |       h5eee18b_3         759 KB
#     libmamba-2.0.5             |       haf1ee3a_1         2.2 MB
#     libmambapy-2.0.5           |  py312hdb19cb5_1         672 KB
#     libpng-1.6.39              |       h5eee18b_0         304 KB
#     librsvg-2.56.3             |       h056759b_0         5.2 MB
#     libsolv-0.7.30             |       he621ea3_1         492 KB
#     libtiff-4.5.1              |       hffd6297_1         534 KB
#     libtool-2.4.6              |    h6a678d5_1009         421 KB
#     libwebp-1.2.4              |       h11a3e52_1          86 KB
#     libwebp-base-1.2.4         |       h5eee18b_1         376 KB
#     libxcb-1.15                |       h7f8727e_0         505 KB
#     libxml2-2.13.5             |       hfdd30dd_0         738 KB
#     ninja-1.12.1               |       h06a4308_0           8 KB
#     ninja-base-1.12.1          |       hdb19cb5_0         157 KB
#     nlohmann_json-3.11.2       |       h6a678d5_0         124 KB
#     nspr-4.35                  |       h6a678d5_0         244 KB
#     nss-3.89.1                 |       h6a678d5_0         2.1 MB
#     openjpeg-2.5.2             |       he7f1fd0_0         371 KB
#     pango-1.50.7               |       h05da053_0         427 KB
#     pixman-0.40.0              |       h7f8727e_1         373 KB
#     poppler-24.09.0            |       hcf11d46_1        20.0 MB
#     poppler-data-0.4.11        |       h06a4308_1         2.6 MB
#     simdjson-3.10.1            |       hdb19cb5_0         258 KB
#     spdlog-1.11.0              |       hdb19cb5_0         234 KB
#     ------------------------------------------------------------
#                                            Total:        79.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   atk-1.0            pkgs/main/linux-64::atk-1.0-2.36.0-ha1a6a79_0
#   boost-cpp          pkgs/main/linux-64::boost-cpp-1.82.0-hdb19cb5_2
#   cairo              pkgs/main/linux-64::cairo-1.16.0-hb05425b_5
#   cpp-expected       pkgs/main/linux-64::cpp-expected-1.1.0-hdb19cb5_0
#   font-ttf-dejavu-s~ pkgs/main/noarch::font-ttf-dejavu-sans-mono-2.37-hd3eb1b0_0
#   font-ttf-inconsol~ pkgs/main/noarch::font-ttf-inconsolata-2.001-hcb22688_0
#   font-ttf-source-c~ pkgs/main/noarch::font-ttf-source-code-pro-2.030-hd3eb1b0_0
#   font-ttf-ubuntu    pkgs/main/noarch::font-ttf-ubuntu-0.83-h8b1ccd4_0
#   fontconfig         pkgs/main/linux-64::fontconfig-2.14.1-h55d465d_3
#   fonts-anaconda     pkgs/main/noarch::fonts-anaconda-1-h8fa9717_0
#   fonts-conda-ecosy~ pkgs/main/noarch::fonts-conda-ecosystem-1-hd3eb1b0_0
#   freetype           pkgs/main/linux-64::freetype-2.12.1-h4a9f257_0
#   fribidi            pkgs/main/linux-64::fribidi-1.0.10-h7b6447c_0
#   gdk-pixbuf         pkgs/main/linux-64::gdk-pixbuf-2.42.10-h5eee18b_1
#   giflib             pkgs/main/linux-64::giflib-5.2.2-h5eee18b_0
#   glib               pkgs/main/linux-64::glib-2.78.4-h6a678d5_0
#   glib-tools         pkgs/main/linux-64::glib-tools-2.78.4-h6a678d5_0
#   gobject-introspec~ pkgs/main/linux-64::gobject-introspection-1.78.1-py312h42194e9_2
#   graphite2          pkgs/main/linux-64::graphite2-1.3.14-h295c915_1
#   graphviz           pkgs/main/linux-64::graphviz-2.50.0-h78213b7_2
#   gtk2               pkgs/main/linux-64::gtk2-2.24.33-h73c1081_2
#   gts                pkgs/main/linux-64::gts-0.7.6-hb67d8dd_3
#   harfbuzz           pkgs/main/linux-64::harfbuzz-4.3.0-hf52aaf7_2
#   jpeg               pkgs/main/linux-64::jpeg-9e-h5eee18b_3
#   lcms2              pkgs/main/linux-64::lcms2-2.16-hb9589c4_0
#   lerc               pkgs/main/linux-64::lerc-4.0.0-h6a678d5_0
#   libboost           pkgs/main/linux-64::libboost-1.82.0-h109eef0_2
#   libdeflate         pkgs/main/linux-64::libdeflate-1.22-h5eee18b_0
#   libgd              pkgs/main/linux-64::libgd-2.3.3-h6a678d5_3
#   libglib            pkgs/main/linux-64::libglib-2.78.4-hdc74915_0
#   libiconv           pkgs/main/linux-64::libiconv-1.16-h5eee18b_3
#   libpng             pkgs/main/linux-64::libpng-1.6.39-h5eee18b_0
#   librsvg            pkgs/main/linux-64::librsvg-2.56.3-h056759b_0
#   libtiff            pkgs/main/linux-64::libtiff-4.5.1-hffd6297_1
#   libtool            pkgs/main/linux-64::libtool-2.4.6-h6a678d5_1009
#   libwebp            pkgs/main/linux-64::libwebp-1.2.4-h11a3e52_1
#   libwebp-base       pkgs/main/linux-64::libwebp-base-1.2.4-h5eee18b_1
#   libxcb             pkgs/main/linux-64::libxcb-1.15-h7f8727e_0
#   ninja              pkgs/main/linux-64::ninja-1.12.1-h06a4308_0
#   ninja-base         pkgs/main/linux-64::ninja-base-1.12.1-hdb19cb5_0
#   nlohmann_json      pkgs/main/linux-64::nlohmann_json-3.11.2-h6a678d5_0
#   nspr               pkgs/main/linux-64::nspr-4.35-h6a678d5_0
#   nss                pkgs/main/linux-64::nss-3.89.1-h6a678d5_0
#   openjpeg           pkgs/main/linux-64::openjpeg-2.5.2-he7f1fd0_0
#   pango              pkgs/main/linux-64::pango-1.50.7-h05da053_0
#   pixman             pkgs/main/linux-64::pixman-0.40.0-h7f8727e_1
#   poppler            pkgs/main/linux-64::poppler-24.09.0-hcf11d46_1
#   poppler-data       pkgs/main/linux-64::poppler-data-0.4.11-h06a4308_1
#   simdjson           pkgs/main/linux-64::simdjson-3.10.1-hdb19cb5_0
#   spdlog             pkgs/main/linux-64::spdlog-1.11.0-hdb19cb5_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2024.11.26-h06a4308_0 --> 2024.12.31-h06a4308_0
#   certifi                         2024.8.30-py312h06a4308_0 --> 2024.12.14-py312h06a4308_0
#   conda                             24.11.1-py312h06a4308_0 --> 25.1.0-py312h06a4308_0
#   conda-libmamba-so~                    24.1.0-pyhd3eb1b0_0 --> 25.1.1-pyhd3eb1b0_0
#   expat                                    2.6.2-h6a678d5_0 --> 2.6.4-h6a678d5_0
#   libarchive                               3.6.2-h6ac8c49_3 --> 3.7.7-hfab0078_0
#   libmamba                                 1.5.8-hfe524e5_2 --> 2.0.5-haf1ee3a_1
#   libmambapy                          1.5.8-py312h2dafd23_2 --> 2.0.5-py312hdb19cb5_1
#   libsolv                                 0.7.24-he621ea3_1 --> 0.7.30-he621ea3_1
#   libxml2                                 2.10.4-hfdd30dd_2 --> 2.13.5-hfdd30dd_0
#
#
#
# Downloading and Extracting Packages:
# poppler-24.09.0      | 20.0 MB   |                                       |   0%
# libboost-1.82.0      | 19.5 MB   |                                       |   0%
#
# librsvg-2.56.3       | 5.2 MB    |                                       |   0%
#
#
# gtk2-2.24.33         | 3.3 MB    |                                       |   0%
#
#
#
# graphviz-2.50.0      | 2.6 MB    |                                       |   0%
#
#
#
#
# poppler-data-0.4.11  | 2.6 MB    |                                       |   0%
#
#
#
#
#
# libmamba-2.0.5       | 2.2 MB    |                                       |   0%
#
#
#
#
#
#
# nss-3.89.1           | 2.1 MB    |                                       |   0%
#
#
#
#
#
#
#
# gobject-introspectio | 1.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# libglib-2.78.4       | 1.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# conda-25.1.0         | 1.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarchive-3.7.7     | 936 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.16        | 759 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.5       | 738 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libmambapy-2.0.5     | 672 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.12.1      | 626 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 602 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.5.1        | 534 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.78.4          | 508 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libboost-1.82.0      | 19.5 MB   | ##########5                           |  28%
#
#
# gtk2-2.24.33         | 3.3 MB    | ##################################### | 100%
#
#
# gtk2-2.24.33         | 3.3 MB    | ##################################### | 100%
#
#
#
#
# poppler-data-0.4.11  | 2.6 MB    | 2                                     |   1%
#
#
#
#
# poppler-data-0.4.11  | 2.6 MB    | ##################################### | 100%
#
#
#
#
#
# libmamba-2.0.5       | 2.2 MB    | 2                                     |   1%
# libboost-1.82.0      | 19.5 MB   | ######################9               |  62%
#
#
#
#
#
# libmamba-2.0.5       | 2.2 MB    | ##################################### | 100%
#
#
#
#
#
#
# nss-3.89.1           | 2.1 MB    | 2                                     |   1%
# libboost-1.82.0      | 19.5 MB   | ##################################3   |  93%
#
#
#
#
#
#
# nss-3.89.1           | 2.1 MB    | ##################################### | 100%
#
# librsvg-2.56.3       | 5.2 MB    | 1                                     |   0%
#
#
#
# graphviz-2.50.0      | 2.6 MB    | 2                                     |   1%
#
# librsvg-2.56.3       | 5.2 MB    | #4                                    |   4%
# libboost-1.82.0      | 19.5 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
# libglib-2.78.4       | 1.5 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
# libglib-2.78.4       | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.3 MB    | 4                                     |   1%
#
# librsvg-2.56.3       | 5.2 MB    | ##5                                   |   7%
#
#
#
#
# poppler-data-0.4.11  | 2.6 MB    | ##################################### | 100%
#
#
#
#
# poppler-data-0.4.11  | 2.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.2 MB    | 5                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# conda-25.1.0         | 1.2 MB    | 5                                     |   1%
#
# poppler-24.09.0      | 20.0 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# conda-25.1.0         | 1.2 MB    | ##################################### | 100%
#
#
#
# graphviz-2.50.0      | 2.6 MB    | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarchive-3.7.7     | 936 KB    | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarchive-3.7.7     | 936 KB    | ##################################### | 100%
#
#
# gtk2-2.24.33         | 3.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.16        | 759 KB    | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.16        | 759 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.5       | 738 KB    | 8                                     |   2%
#
# librsvg-2.56.3       | 5.2 MB    | #####3                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# poppler-24.09.0      | 20.0 MB   | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libmambapy-2.0.5     | 672 KB    | 8                                     |   2%
#
#
#
#
#
# libmamba-2.0.5       | 2.2 MB    | ##################################### | 100%
#
#
#
#
#
# libmamba-2.0.5       | 2.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libmambapy-2.0.5     | 672 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | 9                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.12.1      | 626 KB    | 9                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.12.1      | 626 KB    | ##################################### | 100%
#
# librsvg-2.56.3       | 5.2 MB    | ########1                             |  22%
#
# librsvg-2.56.3       | 5.2 MB    | ##########7                           |  29%
#
#
#
#
#
#
# nss-3.89.1           | 2.1 MB    | ##################################### | 100%
#
#
#
#
#
#
# nss-3.89.1           | 2.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# gobject-introspectio | 1.7 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
# libglib-2.78.4       | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libglib-2.78.4       | 1.5 MB    | ##################################### | 100%
#
# librsvg-2.56.3       | 5.2 MB    | ##############6                       |  40%
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################################### | 100%
#
#
#
# graphviz-2.50.0      | 2.6 MB    | ##                                    |   5%
#
# librsvg-2.56.3       | 5.2 MB    | ###################2                  |  52%
#
#
#
#
#
#
#
# poppler-24.09.0      | 20.0 MB   | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.3 MB    | ##################################### | 100%
#
#
#
# graphviz-2.50.0      | 2.6 MB    | ##########                            |  27%
#
#
#
#
#
#
#
# poppler-24.09.0      | 20.0 MB   | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# gobject-introspectio | 1.7 MB    | ######3                               |  17%
#
#
#
# poppler-24.09.0      | 20.0 MB   | #2                                    |   3%
#
# librsvg-2.56.3       | 5.2 MB    | #########################3            |  69%
#
#
#
#
#
#
#
# gobject-introspectio | 1.7 MB    | ########6                             |  23%
#
#
#
# graphviz-2.50.0      | 2.6 MB    | #######################9              |  65%
#
# librsvg-2.56.3       | 5.2 MB    | ##################################### | 100%
#
# librsvg-2.56.3       | 5.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.5.1        | 534 KB    | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.5.1        | 534 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.78.4          | 508 KB    | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.78.4          | 508 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# graphviz-2.50.0      | 2.6 MB    | ############################6         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
# conda-25.1.0         | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# conda-25.1.0         | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarchive-3.7.7     | 936 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarchive-3.7.7     | 936 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.16        | 759 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.16        | 759 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# gobject-introspectio | 1.7 MB    | ##########6                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.5       | 738 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.5       | 738 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libmambapy-2.0.5     | 672 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libmambapy-2.0.5     | 672 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 602 KB    | 9                                     |   3%
#
#
#
#
#
#
#
# gobject-introspectio | 1.7 MB    | ##############6                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.12.1      | 626 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# poppler-24.09.0      | 20.0 MB   | #4                                    |   4%
#
# poppler-24.09.0      | 20.0 MB   | #7                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.5.1        | 534 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.5.1        | 534 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# gobject-introspectio | 1.7 MB    | ##########################7           |  72%
#
#
#
# graphviz-2.50.0      | 2.6 MB    | ################################6     |  88%
#
#
#
# graphviz-2.50.0      | 2.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 602 KB    | ###9                                  |  11%
#
#
#
#
#
#
#
# gobject-introspectio | 1.7 MB    | #############################3        |  79%
#
#
#
#
#
#
#
# gobject-introspectio | 1.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.78.4          | 508 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# poppler-24.09.0      | 20.0 MB   | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 602 KB    | #######8                              |  21%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# poppler-24.09.0      | 20.0 MB   | ##4                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# poppler-24.09.0      | 20.0 MB   | ###                                   |   8%
#
#
#
# graphviz-2.50.0      | 2.6 MB    | ##################################### | 100%
#
#
#
# poppler-24.09.0      | 20.0 MB   | ###2                                  |   9%
#
#
#
#
#
#
#
# gobject-introspectio | 1.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# poppler-24.09.0      | 20.0 MB   | #####4                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 602 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# poppler-24.09.0      | 20.0 MB   | #########8                            |  27%
# poppler-24.09.0      | 20.0 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# donearing transaction: -
# donefying transaction: \
# doneuting transaction: -

# %%
# Importing required packages for visualization
from IPython.display import Image  
from six import StringIO
from sklearn.tree import export_graphviz
import pydotplus, graphviz

# %%
# plotting tree with max_depth=3
dot_data = StringIO()  

export_graphviz(dt, out_file=dot_data, filled=True, rounded=True,
                feature_names=X.columns, 
                class_names=['No Disease', "Disease"])

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
#Image(graph.create_png(),width=800,height=900)
#graph.write_pdf("dt_heartdisease.pdf")

# %% [markdown]
# #### Evaluating model performance

# %%
y_train_pred = dt.predict(X_train)
y_test_pred = dt.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
print(accuracy_score(y_train, y_train_pred))
confusion_matrix(y_train, y_train_pred)
# Out:
# 0.7407407407407407
# array([[82, 19],
#        [30, 58]])

# %%
print(accuracy_score(y_test, y_test_pred))
confusion_matrix(y_test, y_test_pred)
# Out:
# 0.6049382716049383
# array([[35, 14],
#        [18, 14]])
