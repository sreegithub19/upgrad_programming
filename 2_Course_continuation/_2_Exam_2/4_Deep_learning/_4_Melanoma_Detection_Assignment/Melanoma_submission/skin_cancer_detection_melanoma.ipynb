# %% [markdown]
# # <font color=red> Melanoma Detection (TO BE DONE IN GOOGLE COLAB)

# %% [markdown]
# ## <font color=green>Bookmarks to Notebook Sections
#  - [Importing all the important libraries](#import_libraries)
#  - [Data Preparation](#data_preparation)
#  - - [Train Data Set Creation](#train_data)
#  - - [Validation Data Set Creation](#validation_data)
#  - [Visualizing the Data](#visualize_data)
#  - [Model 0 (with BatchNormalization layers)](#model_0)
#  - - [Creating the Model](#creating_model_0)
#  - - [Compiling the Model](#compiling_model_0)
#  - - [Training the Model](#training_model_0)
#  - - [Visualizing the Training Results](#visualize_results_0)
#  - - [Observations](#observations_0)
#  - [Model 1](#model_1)
#  - - [Creating the Model](#creating_model_1)
#  - - [Compiling the Model](#compiling_model_1)
#  - - [Training the Model](#training_model_1)
#  - - [Visualizing the Training Results](#visualize_results_1)
#  - - [Observations](#observations_1)
#  - [Data Augmentation](#Data_Augmentation)
#  - - [Specifying the Augmentation](#specifying_augmentation)
#  - - [Visualizing the Augmented Data](#visualizing_augmented_data)
#  - [Model 2 (using Data Augmentation) ](#model_2)
#  - - [Creating the Model](#creating_model_2)
#  - - [Compiling the Model](#compiling_model_2)
#  - - [Training the Model](#training_model_2)
#  - - [Visualizing the Training Results](#visualize_results_2)
#  - - [Observations](#observations_2)
#  - [Checking for Class Imbalance](#Checking_for_Class_Imbalance)
#  - [Using Augmentor for Class Imbalance Treatment](#Using_Augmentor_for_Class_Imbalance_Treatment)
#  - - [Installing Augmentor](#Installing_augmentor)
#  - - [Using Augmentor](#Using_augmentor)
#  - - [Observations](#observations)
#  - [Modelling Data using Augmentor](#modelling_data_using_augmentor)
#  - - [Creating the Train Data Set](#creating_train_data_1)
#  - - [Creating the Validation Data Set](#creating_validation_data_1)
#  - [Model 3 (using class rebalance) ]((#model_3)
#  - - [Creating the Model](#creating_model_3)
#  - - [Compiling the Model](#compiling_model_3)
#  - - [Training the Model](#training_model_3)
#  - - [Visualizing the Training Results](#visualize_results_3)
#  - - [Observations](#observations_3)

# %% [markdown]
# <h2><a id="import_libraries">1. Importing all the important libraries</a></h2>

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from glob import glob
from tensorflow.keras.layers import Rescaling
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPooling2D
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from IPython.display import Image,display,HTML

# %%
# ## If you are using the data by mounting the google drive, use the following :
# from google.colab import drive
# drive.mount('/content/gdrive')

import kagglehub

# Download latest version
path = kagglehub.dataset_download("jaiahuja/skin-cancer-detection")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.6), please consider upgrading to the latest version (0.3.7).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/jaiahuja/skin-cancer-detection?dataset_version_number=1...
# 100%|██████████| 786M/786M [00:10<00:00, 80.9MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/jaiahuja/skin-cancer-detection/versions/1

# %% [markdown]
# This dataset has about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
trained_path="/root/.cache/kagglehub/datasets/jaiahuja/skin-cancer-detection/versions/1/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
tested_path="/root/.cache/kagglehub/datasets/jaiahuja/skin-cancer-detection/versions/1/Skin cancer ISIC The International Skin Imaging Collaboration/Test/"
data_directory_train = pathlib.Path(trained_path)
data_directory_test = pathlib.Path(tested_path)

# %%
image_count_train = len(list(data_directory_train.glob('*/*.jpg')))
display(image_count_train)
image_count_test = len(list(data_directory_test.glob('*/*.jpg')))
display(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# <h2><a id="data_preparation">2. Data Preparation</a></h2>

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %% [markdown]
# <h3><a id="train_data">2.1 Train Data Set Creation</a></h3>

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_directory_train, labels='inferred', label_mode='categorical',
    class_names=None, color_mode='rgb', batch_size=32, image_size=(180,
    180), shuffle=True, seed=123, validation_split=0.2, subset='training',
    interpolation='bilinear', follow_links=False
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %% [markdown]
# <h3><a id="validation_data">2.2 Validation Data Set Creation</a></h3>

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_directory_train, labels='inferred', label_mode='categorical',
    class_names=None, color_mode='rgb', batch_size=32, image_size=(180,
    180), shuffle=True, seed=123, validation_split=0.2, subset='validation',
    interpolation='bilinear', follow_links=False
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
class_names = train_ds.class_names
display(class_names)
# Out:
# ['actinic keratosis',
#  'basal cell carcinoma',
#  'dermatofibroma',
#  'melanoma',
#  'nevus',
#  'pigmented benign keratosis',
#  'seborrheic keratosis',
#  'squamous cell carcinoma',
#  'vascular lesion']

# %% [markdown]
# <h2><a id="visualize_data">3. Visualizing the data </a></h2>

# %%
import matplotlib.pyplot as plt
num=0
for dirpath, dirnames, filenames in os.walk(str(trained_path)):
    for filename in [f for f in filenames if f.endswith(".jpg")][:1]:
        img = PIL.Image.open(str(dirpath)+"/"+str(filename))
        plt.subplot(3,3,num+1)
        plt.title(str(dirpath).split('/')[-1])
        plt.axis('off')
        plt.imshow(img)
        num=num+1

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# <h2><a id="model_0">4. Model 0 (with BatchNormalization layers)</a></h2>

# %% [markdown]
# <h3><a id="creating_model_0">4.1 Creating the model</a></h3>

# %%
model=Sequential([
    tf.keras.layers.Rescaling(scale=1./255., offset=0.0,),

    Conv2D(32,(3,3),input_shape=(img_height,img_width,3),activation='relu',padding='same'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.1),

    Conv2D(64,(3,3),activation='relu',padding='same'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.1),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.25),
    Dense(9, activation='softmax')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# <h3><a id="compiling_model_0">4.2 Compiling the model</a></h3>

# %%
### Selecting an appropriate optimiser and loss function
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# <h3><a id="training_model_0">4.3 Training the model </a></h3>

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 26s 124ms/step - accuracy: 0.1960 - loss: 3.6937 - val_accuracy: 0.2528 - val_loss: 2.0500
# Epoch 2/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.2840 - loss: 1.9542 - val_accuracy: 0.3132 - val_loss: 1.8323
# Epoch 3/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.4019 - loss: 1.6655 - val_accuracy: 0.5078 - val_loss: 1.5199
# Epoch 4/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.5111 - loss: 1.4754 - val_accuracy: 0.5459 - val_loss: 1.3772
# Epoch 5/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.5532 - loss: 1.3412 - val_accuracy: 0.4966 - val_loss: 1.4823
# Epoch 6/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.5775 - loss: 1.2939 - val_accuracy: 0.5145 - val_loss: 1.3838
# Epoch 7/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.5983 - loss: 1.1841 - val_accuracy: 0.5347 - val_loss: 1.3565
# Epoch 8/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.6069 - loss: 1.1254 - val_accuracy: 0.4720 - val_loss: 1.4313
# Epoch 9/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.6522 - loss: 0.9758 - val_accuracy: 0.5570 - val_loss: 1.3327
# Epoch 10/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.6726 - loss: 0.8907 - val_accuracy: 0.5257 - val_loss: 1.4410
# Epoch 11/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.7181 - loss: 0.8268 - val_accuracy: 0.5503 - val_loss: 1.4692
# Epoch 12/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.7168 - loss: 0.7964 - val_accuracy: 0.5682 - val_loss: 1.5694
# Epoch 13/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.7686 - loss: 0.6788 - val_accuracy: 0.5481 - val_loss: 1.6443
# Epoch 14/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.7683 - loss: 0.6131 - val_accuracy: 0.5190 - val_loss: 1.7041
# Epoch 15/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.7724 - loss: 0.5996 - val_accuracy: 0.5503 - val_loss: 1.5979
# Epoch 16/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.8207 - loss: 0.5158 - val_accuracy: 0.5503 - val_loss: 1.6723
# Epoch 17/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.8449 - loss: 0.4377 - val_accuracy: 0.5324 - val_loss: 2.0132
# Epoch 18/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.8392 - loss: 0.4204 - val_accuracy: 0.5123 - val_loss: 2.0391
# Epoch 19/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.8490 - loss: 0.3926 - val_accuracy: 0.5459 - val_loss: 1.8120
# Epoch 20/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.8769 - loss: 0.3568 - val_accuracy: 0.5593 - val_loss: 1.7702

# %%
# Viewing the summary of all layers
display(
    model.summary(),
)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)                │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 180, 180, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 90, 90, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 90, 90, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 90, 90, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 45, 45, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 45, 45, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 129600)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │      16,588,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 9)                   │           1,161 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 49,828,445 (190.08 MB)
#  Trainable params: 16,609,481 (63.36 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 33,218,964 (126.72 MB)
# None

# %% [markdown]
# <h3><a id="visualize_results_0">4.4 Visualizing training results </a></h3>

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
display(plt.show())
# Out:
# None

# %% [markdown]
# <h3><a id="observations_0">4.5 Observations </a></h3>

# %% [markdown]
# -  The accuracy of the model for the **Training data set** is at **78%**. But the **Validation accuracy** is not in par with the training accuracy.
# -  It is only at **53%**. The validation loss as observed is very high.
# -  This could also be indicative of some **Overfit** in the model.
# -  We could add some `Dropout` layers and remove the `BatchNormalization` layers.
# -  And by adding a few more layers, we could improve the accuracy by trying to extract more features.

# %% [markdown]
# <h2><a id="model_1">5. Model 1  </a></h2>

# %% [markdown]
# <h3><a id="creating_model_1">5.1 Creating the Model </a></h3>

# %%
model_update=Sequential([
    tf.keras.layers.Rescaling(scale=1./255., offset=0.0,),

    Conv2D(32,(3,3),input_shape=(img_height,img_width,3),activation='relu',padding='same'),
    Conv2D(32,(3,3),activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.7),

    Conv2D(64,(3,3),activation='relu',padding='same'),
    Conv2D(64,(3,3),activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.7),

    Conv2D(128,(3,3),activation='relu',padding='same'),
    Conv2D(128,(3,3),activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.7),

    Flatten(),
    Dense(100, activation='relu'),
    Dropout(0.25),
    Dense(9, activation='softmax')
])

# %% [markdown]
# <h3><a id="compiling_model_1">5.2 Compiling the model  </a></h3>

# %%
model_update.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# <h3><a id="training_model_1">5.3 Training the model </a></h3>

# %%
epochs = 20
history = model_update.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 23s 160ms/step - accuracy: 0.1851 - loss: 2.3294 - val_accuracy: 0.1499 - val_loss: 2.0326
# Epoch 2/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.1823 - loss: 2.0157 - val_accuracy: 0.2058 - val_loss: 2.0350
# Epoch 3/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.2028 - loss: 2.0407 - val_accuracy: 0.1924 - val_loss: 2.0289
# Epoch 4/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.1781 - loss: 2.0544 - val_accuracy: 0.2058 - val_loss: 2.0227
# Epoch 5/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.1875 - loss: 2.0185 - val_accuracy: 0.2058 - val_loss: 2.0225
# Epoch 6/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.2018 - loss: 2.0095 - val_accuracy: 0.2058 - val_loss: 2.0239
# Epoch 7/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.1932 - loss: 2.0303 - val_accuracy: 0.2058 - val_loss: 2.0232
# Epoch 8/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.1997 - loss: 2.0221 - val_accuracy: 0.1946 - val_loss: 2.0225
# Epoch 9/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2191 - loss: 1.9862 - val_accuracy: 0.3378 - val_loss: 1.8710
# Epoch 10/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.2759 - loss: 1.9150 - val_accuracy: 0.3065 - val_loss: 1.8680
# Epoch 11/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.3167 - loss: 1.8493 - val_accuracy: 0.3154 - val_loss: 1.8818
# Epoch 12/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.3415 - loss: 1.7367 - val_accuracy: 0.2640 - val_loss: 1.9288
# Epoch 13/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.3356 - loss: 1.7903 - val_accuracy: 0.3244 - val_loss: 1.7974
# Epoch 14/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.3690 - loss: 1.7000 - val_accuracy: 0.3423 - val_loss: 1.8109
# Epoch 15/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.3931 - loss: 1.6646 - val_accuracy: 0.2662 - val_loss: 1.9485
# Epoch 16/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.4137 - loss: 1.6198 - val_accuracy: 0.2707 - val_loss: 1.9437
# Epoch 17/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.4080 - loss: 1.6290 - val_accuracy: 0.2617 - val_loss: 1.9656
# Epoch 18/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.4230 - loss: 1.6030 - val_accuracy: 0.3557 - val_loss: 1.7605
# Epoch 19/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.4111 - loss: 1.5906 - val_accuracy: 0.3579 - val_loss: 1.7750
# Epoch 20/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.4469 - loss: 1.5218 - val_accuracy: 0.3400 - val_loss: 1.8199

# %% [markdown]
# <h3><a id="visualize_results_1">5.4 Visualizing the results  </a></h3>

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
display(plt.show())
# Out:
# None

# %% [markdown]
# <h3><a id="observations_1">5.5 Observations </a></h3>

# %% [markdown]
# -  The model accuracy for **Train data set** has dropped to nearly **45%**.
# -  The accuracy for the **Validation set** is at **40%**.
# -  This is a much better model compared to the previous model as there seems to be **No Overfit** with the training accuracy **45%** and validation accuracy at **40%**.

# %% [markdown]
# <h2><a id="Data_Augmentation">6. Data Augmentation </a></h2>

# %% [markdown]
# <h3><a id="specifying_augmentation">6.1 Specifying the Augmentation</a></h3>

# %%
data_augmentation=tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2)
])

# %% [markdown]
# <h3><a id="visualizing_augmented_data">6.2 Visualizing the Augmented Data</a></h3>

# %%
image, label = next(iter(train_ds))
image=np.array(image,np.int32)
plt.figure(figsize=(10, 10))
for i in range(9):
  augmented_image = data_augmentation(image)
  ax = plt.subplot(3, 3, i + 1)
  augmented_image1=np.array(augmented_image[0],np.int32)
  plt.imshow((augmented_image1))
  plt.axis("off")

# %% [markdown]
# <h2><a id="model_2">7. Model 2 (using Data Augmentation) </a></h2>

# %% [markdown]
# <h3><a id="creating_model_2">7.1 Creating the Model </a></h3>

# %%
model_augmented=Sequential([
    tf.keras.layers.Rescaling(scale=1./255., offset=0.0,),

    data_augmentation,

    Conv2D(32,(3,3),input_shape=(img_height,img_width,3),activation='relu',padding='same'),
    Conv2D(32,(3,3),activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.7),

    Conv2D(64,(3,3),activation='relu',padding='same'),
    Conv2D(64,(3,3),activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.7),

    Conv2D(128,(3,3),activation='relu',padding='same'),
    Conv2D(128,(3,3),activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.7),

    Flatten(),
    Dense(100, activation='relu'),
    Dropout(0.25),
    Dense(9, activation='softmax')
])

# %% [markdown]
# <h3><a id="compiling_model_2">7.2 Compiling the model </a></h3>

# %%
model_augmented.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# <h3><a id="training_model_2">7.3 Training the model </a></h3>

# %%
epochs = 20
history = model_augmented.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 130ms/step - accuracy: 0.1715 - loss: 2.2594 - val_accuracy: 0.1924 - val_loss: 2.0570
# Epoch 2/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.1950 - loss: 2.0392 - val_accuracy: 0.2058 - val_loss: 2.0200
# Epoch 3/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 115ms/step - accuracy: 0.2521 - loss: 1.9980 - val_accuracy: 0.2215 - val_loss: 2.0195
# Epoch 4/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.2601 - loss: 1.9653 - val_accuracy: 0.3266 - val_loss: 1.8492
# Epoch 5/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.3398 - loss: 1.7883 - val_accuracy: 0.4049 - val_loss: 1.6735
# Epoch 6/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.3679 - loss: 1.6613 - val_accuracy: 0.3043 - val_loss: 1.8952
# Epoch 7/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.3703 - loss: 1.7267 - val_accuracy: 0.2998 - val_loss: 1.8636
# Epoch 8/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.3811 - loss: 1.6889 - val_accuracy: 0.2662 - val_loss: 1.9404
# Epoch 9/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.3651 - loss: 1.7500 - val_accuracy: 0.4273 - val_loss: 1.6015
# Epoch 10/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.4114 - loss: 1.6272 - val_accuracy: 0.4541 - val_loss: 1.5898
# Epoch 11/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.4508 - loss: 1.5573 - val_accuracy: 0.4519 - val_loss: 1.5678
# Epoch 12/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 114ms/step - accuracy: 0.4017 - loss: 1.6524 - val_accuracy: 0.4004 - val_loss: 1.6860
# Epoch 13/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.4369 - loss: 1.5625 - val_accuracy: 0.3937 - val_loss: 1.7199
# Epoch 14/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.4436 - loss: 1.5572 - val_accuracy: 0.4094 - val_loss: 1.6522
# Epoch 15/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.4519 - loss: 1.5313 - val_accuracy: 0.4206 - val_loss: 1.6380
# Epoch 16/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.4535 - loss: 1.5245 - val_accuracy: 0.3758 - val_loss: 1.7049
# Epoch 17/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.4614 - loss: 1.5147 - val_accuracy: 0.3781 - val_loss: 1.7424
# Epoch 18/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.4659 - loss: 1.4937 - val_accuracy: 0.4004 - val_loss: 1.7058
# Epoch 19/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.4915 - loss: 1.4770 - val_accuracy: 0.4116 - val_loss: 1.6537
# Epoch 20/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.4834 - loss: 1.4876 - val_accuracy: 0.4295 - val_loss: 1.5348

# %% [markdown]
# <h3><a id="visualize_results_2">7.4 Visualizing the results  </a></h3>

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
display(plt.show())
# Out:
# None

# %% [markdown]
# <h3><a id="observations_2">7.5  Observations </a></h3>

# %% [markdown]
# -  The model accuracy for **Train data set** has gone up to nearly **48%**.
# -  The accuracy for the **Validation set** is also at **48%**.
# -  This is a much better model compared to the previous two models as there seems to be **No Overfit** with the training accuracy **48%** and validation accuracy at **48%**.
# -  `Data Augmentation` has improved the model performance.

# %% [markdown]
# <h2><a id="Checking_for_Class_Imbalance">8. Checking for Class Imbalance </a></h2>

# %%
for i in class_names:
    directory =trained_path+i+'/'
    class_directory = pathlib.Path(directory)
    length=len(list(class_directory.glob('*.jpg')))
    display(f'{i} has {length} samples.')
# Out:
# 'actinic keratosis has 114 samples.'
# 'basal cell carcinoma has 376 samples.'
# 'dermatofibroma has 95 samples.'
# 'melanoma has 438 samples.'
# 'nevus has 357 samples.'
# 'pigmented benign keratosis has 462 samples.'
# 'seborrheic keratosis has 77 samples.'
# 'squamous cell carcinoma has 181 samples.'
# 'vascular lesion has 139 samples.'

# %% [markdown]
# -  The samples of various classes are not in equal proportion.
# -  There is a significant **Class Imbalance** observed.
# -  The class with the least number of samples is `Seborrheic Keratosis` with **77**.
# -  The class that dominates the data in terms of proportionate number of samples is `Pigmented Benign Keratosis` with sample size of **462**.

# %% [markdown]
# <h2><a id="Using_Augmentor_for_Class_Imbalance_Treatment">9. Using Augmentor for Class Imbalance Treatment</a></h2>

# %% [markdown]
# <h3><a id="Installing_augmentor">9.1 Installing Augmentor</a></h3>

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.11/dist-packages (from Augmentor) (11.1.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from Augmentor) (4.67.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from Augmentor) (1.26.4)
# Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %% [markdown]
# <h3><a id="Using_augmentor">9.2 Using Augmentor </a></h3>

# %%
path_to_training_dataset=trained_path
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /root/.cache/kagglehub/datasets/jaiahuja/skin-cancer-detection/versions/1/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7BE61048FE50>: 100%|██████████| 500/500 [00:18<00:00, 26.73 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /root/.cache/kagglehub/datasets/jaiahuja/skin-cancer-detection/versions/1/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7BE61030CFD0>: 100%|██████████| 500/500 [00:16<00:00, 31.02 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /root/.cache/kagglehub/datasets/jaiahuja/skin-cancer-detection/versions/1/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7BE610415290>: 100%|██████████| 500/500 [00:14<00:00, 35.23 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /root/.cache/kagglehub/datasets/jaiahuja/skin-cancer-detection/versions/1/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7BE6102C2F10>: 100%|██████████| 500/500 [01:04<00:00,  7.81 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /root/.cache/kagglehub/datasets/jaiahuja/skin-cancer-detection/versions/1/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=919x802 at 0x7BE61030DB90>: 100%|██████████| 500/500 [01:12<00:00,  6.90 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /root/.cache/kagglehub/datasets/jaiahuja/skin-cancer-detection/versions/1/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7BE610475450>: 100%|██████████| 500/500 [00:14<00:00, 35.02 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /root/.cache/kagglehub/datasets/jaiahuja/skin-cancer-detection/versions/1/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7BE610331CD0>: 100%|██████████| 500/500 [00:34<00:00, 14.61 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /root/.cache/kagglehub/datasets/jaiahuja/skin-cancer-detection/versions/1/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7BE610303110>: 100%|██████████| 500/500 [00:14<00:00, 34.81 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /root/.cache/kagglehub/datasets/jaiahuja/skin-cancer-detection/versions/1/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7BE610477210>: 100%|██████████| 500/500 [00:14<00:00, 34.97 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_directory_train.glob('*/output/*.jpg')))
display(image_count_train)
# Out:
# 4500

# %%
path_list = [x for x in glob(os.path.join(data_directory_train, '*','output', '*.jpg'))]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_directory_train, '*','output', '*.jpg'))]

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
for i in class_names:
    directory =trained_path+i+'/'
    directory_out =trained_path+i+'/output/'
    class_directory = pathlib.Path(directory)
    class_directory_out = pathlib.Path(directory_out)
    length=len(list(class_directory.glob('*.jpg')))
    length_out=len(list(class_directory_out.glob('*.jpg')))
    length_tot=length+length_out
    display(f'{i} has {length_tot} samples.')
# Out:
# 'actinic keratosis has 614 samples.'
# 'basal cell carcinoma has 876 samples.'
# 'dermatofibroma has 595 samples.'
# 'melanoma has 938 samples.'
# 'nevus has 857 samples.'
# 'pigmented benign keratosis has 962 samples.'
# 'seborrheic keratosis has 577 samples.'
# 'squamous cell carcinoma has 681 samples.'
# 'vascular lesion has 639 samples.'

# %% [markdown]
# <h3><a id="observations">9.3 Observations </a></h3>

# %% [markdown]
# -  The Augmentor has **helped decrease the imbalance** in class images and that can be viewed from above.

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# <h2><a id="modelling_data_using_augmentor">10. Modelling Augmented Data</a></h2>

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# <h3><a id="creating_train_data_1">10.1 Creating the Train Data Set</a></h3>

# %%
data_directory_train=trained_path
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_directory_train,
  seed=123, label_mode='categorical',
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# <h3><a id="creating_validation_data_1">10.2 Creating the Validation Data Set</a></h3>

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_directory_train,
  seed=123, label_mode='categorical',
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# <h2><a id="model_3">11. Model 3 (using class rebalance) </a></h2>

# %% [markdown]
# <h3><a id="creating_model_3">11.1 Creating the Model</a></h3>

# %%
model_final=Sequential([
    tf.keras.layers.Rescaling(scale=1./255., offset=0.0,),

    Conv2D(32,(3,3),input_shape=(img_height,img_width,3),activation='relu',padding='same'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.1),

    Conv2D(64,(3,3),activation='relu',padding='same'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.1),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.25),
    Dense(9, activation='softmax')
])

# %% [markdown]
# <h3><a id="compiling_model_3">11.2 Compiling the Model </a></h3>

# %%
model_final.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# <h3><a id="training_model_3">11.3 Training the Model </a></h3>

# %%
epochs = 30

history = model_final.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 37s 185ms/step - accuracy: 0.1987 - loss: 3.1693 - val_accuracy: 0.4024 - val_loss: 1.7264
# Epoch 2/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 22s 132ms/step - accuracy: 0.4059 - loss: 1.5769 - val_accuracy: 0.5286 - val_loss: 1.3442
# Epoch 3/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 135ms/step - accuracy: 0.5111 - loss: 1.3410 - val_accuracy: 0.5724 - val_loss: 1.1750
# Epoch 4/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 40s 133ms/step - accuracy: 0.5719 - loss: 1.1686 - val_accuracy: 0.6310 - val_loss: 1.0200
# Epoch 5/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 22s 132ms/step - accuracy: 0.6092 - loss: 1.0643 - val_accuracy: 0.6808 - val_loss: 0.9451
# Epoch 6/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 22s 133ms/step - accuracy: 0.6656 - loss: 0.9427 - val_accuracy: 0.6978 - val_loss: 0.8841
# Epoch 7/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 22s 132ms/step - accuracy: 0.7231 - loss: 0.7633 - val_accuracy: 0.7090 - val_loss: 0.8417
# Epoch 8/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 22s 130ms/step - accuracy: 0.7663 - loss: 0.6588 - val_accuracy: 0.7164 - val_loss: 0.8252
# Epoch 9/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 22s 131ms/step - accuracy: 0.7954 - loss: 0.5858 - val_accuracy: 0.7550 - val_loss: 0.7271
# Epoch 10/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 137ms/step - accuracy: 0.8019 - loss: 0.5450 - val_accuracy: 0.7120 - val_loss: 0.8885
# Epoch 11/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 39s 124ms/step - accuracy: 0.8241 - loss: 0.5027 - val_accuracy: 0.7550 - val_loss: 0.7444
# Epoch 12/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 23s 138ms/step - accuracy: 0.8466 - loss: 0.4151 - val_accuracy: 0.7624 - val_loss: 0.7527
# Epoch 13/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 39s 129ms/step - accuracy: 0.8599 - loss: 0.3742 - val_accuracy: 0.7825 - val_loss: 0.7506
# Epoch 14/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 22s 131ms/step - accuracy: 0.8599 - loss: 0.4043 - val_accuracy: 0.7921 - val_loss: 0.7775
# Epoch 15/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 22s 129ms/step - accuracy: 0.8890 - loss: 0.3341 - val_accuracy: 0.7944 - val_loss: 0.7429
# Epoch 16/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 22s 129ms/step - accuracy: 0.8785 - loss: 0.3273 - val_accuracy: 0.7899 - val_loss: 0.7398
# Epoch 17/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 22s 129ms/step - accuracy: 0.9007 - loss: 0.2647 - val_accuracy: 0.8018 - val_loss: 0.7323
# Epoch 18/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 130ms/step - accuracy: 0.9049 - loss: 0.2405 - val_accuracy: 0.8062 - val_loss: 0.7456
# Epoch 19/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 40s 124ms/step - accuracy: 0.8961 - loss: 0.2888 - val_accuracy: 0.7929 - val_loss: 0.8977
# Epoch 20/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 131ms/step - accuracy: 0.9072 - loss: 0.2626 - val_accuracy: 0.8174 - val_loss: 0.6936
# Epoch 21/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 22s 133ms/step - accuracy: 0.9097 - loss: 0.2346 - val_accuracy: 0.7996 - val_loss: 0.7469
# Epoch 22/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 139ms/step - accuracy: 0.9117 - loss: 0.2275 - val_accuracy: 0.8181 - val_loss: 0.7713
# Epoch 23/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 22s 131ms/step - accuracy: 0.9282 - loss: 0.1918 - val_accuracy: 0.8025 - val_loss: 0.8349
# Epoch 24/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 134ms/step - accuracy: 0.9162 - loss: 0.2025 - val_accuracy: 0.8181 - val_loss: 0.8740
# Epoch 25/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 132ms/step - accuracy: 0.9182 - loss: 0.2052 - val_accuracy: 0.7981 - val_loss: 0.9009
# Epoch 26/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 131ms/step - accuracy: 0.9096 - loss: 0.2284 - val_accuracy: 0.7944 - val_loss: 0.8622
# Epoch 27/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 23s 137ms/step - accuracy: 0.9180 - loss: 0.2150 - val_accuracy: 0.7817 - val_loss: 1.0039
# Epoch 28/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 22s 132ms/step - accuracy: 0.9288 - loss: 0.1769 - val_accuracy: 0.8181 - val_loss: 0.8252
# Epoch 29/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 21s 125ms/step - accuracy: 0.9355 - loss: 0.1711 - val_accuracy: 0.7958 - val_loss: 0.8983
# Epoch 30/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 22s 131ms/step - accuracy: 0.9290 - loss: 0.1803 - val_accuracy: 0.8092 - val_loss: 1.0397

# %% [markdown]
# <h3><a id="visualize_results_3">11.4 Visualizing the model results </a></h3>

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
display(plt.show())
# Out:
# None

# %% [markdown]
# <h3><a id="observations_3">11.5 Observations</a></h3>

# %% [markdown]
# -  The training accuracy seems to be nearly **~90%**.
# -  The validation accuracy is nearly **~80%**.
# -  Though the model accuracy has improved, the **class rebalance** has helped **treat the overfitting to some extent**.
# -  Much better models could be built or tried out using **more epochs and more layers**.

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2025-02-12 23:22:02
