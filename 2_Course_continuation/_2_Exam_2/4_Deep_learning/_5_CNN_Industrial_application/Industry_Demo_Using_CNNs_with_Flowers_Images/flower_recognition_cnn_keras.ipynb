# %% [markdown]
# # Flower Recognition CNN Keras (TO BE RUN IN GOOGLE COLAB)
#
#
# ##### Flower Recognition CNN Keras (IF RUN IN KAGGLE):
# ##### KAGGLE LINK : https://www.kaggle.com/code/sreedharatkaggle/flower-recognition-cnn-keras/edit

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("alxmamaev/flowers-recognition")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.6), please consider upgrading to the latest version (0.3.7).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/alxmamaev/flowers-recognition?dataset_version_number=2...
# 100%|██████████| 225M/225M [00:11<00:00, 20.9MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/alxmamaev/flowers-recognition/versions/2

# %%
# !ls /root/.cache/kagglehub/datasets/alxmamaev/flowers-recognition/versions/2/flowers
# !cd
# Out:
# daisy  dandelion  rose	sunflower  tulip

# %% [markdown]
# ## CONTENTS ::

# %% [markdown]
# [ **1 ) Importing Various Modules**](#content1)

# %% [markdown]
# [ **2 ) Preparing the Data**](#content2)

# %% [markdown]
# [ **3 ) Modelling**](#content3)

# %% [markdown]
# [ **4 ) Evaluating the Model Performance**](#content4)

# %% [markdown]
# [ **5 ) Visualizing Predictons on the Validation Set**](#content5)

# %% [markdown]
# <a id="content1"></a>
# ## 1 ) Importing Various Modules.

# %%
# Ignore  the warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# data visualisation and manipulation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

#configure
# sets matplotlib to inline and displays graphs below the corressponding cell.
# %matplotlib inline
style.use('fivethirtyeight')
sns.set(style='whitegrid',color_codes=True)

#model selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder

#preprocess.
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#dl libraraies
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop
from keras.utils import to_categorical

# specifically for cnn
from keras.layers import Dropout, Flatten,Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization

import tensorflow as tf
import random as rn

# specifically for manipulating zipped images and getting numpy arrays of pixel values of images.
import cv2
import numpy as np
from tqdm import tqdm
import os
from random import shuffle
from zipfile import ZipFile
from PIL import Image

# %% [markdown]
# <a id="content2"></a>
# ## 2 ) Preparing the Data

# %% [markdown]
# ## 2.1) Making the functions to get the training and validation set from the Images

# %%
X=[]
Z=[]
IMG_SIZE=150
FLOWER_DAISY_DIR='/root/.cache/kagglehub/datasets/alxmamaev/flowers-recognition/versions/2/flowers/daisy'
FLOWER_SUNFLOWER_DIR='/root/.cache/kagglehub/datasets/alxmamaev/flowers-recognition/versions/2/flowers/sunflower'
FLOWER_TULIP_DIR='/root/.cache/kagglehub/datasets/alxmamaev/flowers-recognition/versions/2/flowers/tulip'
FLOWER_DANDI_DIR='/root/.cache/kagglehub/datasets/alxmamaev/flowers-recognition/versions/2/flowers/dandelion'
FLOWER_ROSE_DIR='/root/.cache/kagglehub/datasets/alxmamaev/flowers-recognition/versions/2/flowers/rose'

# %%
def assign_label(img,flower_type):
    return flower_type

# %%
def make_train_data(flower_type,DIR):
    for img in tqdm(os.listdir(DIR)):
        label=assign_label(img,flower_type)
        path = os.path.join(DIR,img)
        img = cv2.imread(path,cv2.IMREAD_COLOR)
        img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))

        X.append(np.array(img))
        Z.append(str(label))

# %%
make_train_data('Daisy',FLOWER_DAISY_DIR)
print(len(X))
# Out:
# 100%|██████████| 764/764 [00:01<00:00, 762.55it/s]
# 764

# %%
make_train_data('Sunflower',FLOWER_SUNFLOWER_DIR)
print(len(X))
# Out:
# 100%|██████████| 733/733 [00:01<00:00, 641.66it/s]
# 1497

# %%
make_train_data('Tulip',FLOWER_TULIP_DIR)
print(len(X))
# Out:
# 100%|██████████| 984/984 [00:01<00:00, 776.16it/s]
# 2481

# %%
make_train_data('Dandelion',FLOWER_DANDI_DIR)
print(len(X))
# Out:
# 100%|██████████| 1052/1052 [00:01<00:00, 802.54it/s]
# 3533

# %%
make_train_data('Rose',FLOWER_ROSE_DIR)
print(len(X))
# Out:
# 100%|██████████| 784/784 [00:00<00:00, 830.00it/s]
# 4317

# %% [markdown]
# ## 2.2 ) Visualizing some Random Images

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=rn.randint(0,len(Z))
        ax[i,j].imshow(X[l])
        ax[i,j].set_title('Flower: '+Z[l])

plt.tight_layout()

# %% [markdown]
# ## 2.3 ) Label Encoding the Y array (i.e. Daisy->0, Rose->1 etc...) & then One Hot Encoding

# %%
le=LabelEncoder()
Y=le.fit_transform(Z)
Y=to_categorical(Y,5)
X=np.array(X)
X=X/255

# %% [markdown]
# ## 2.4 ) Splitting into Training and Validation Sets

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=42)

# %% [markdown]
# ## 2.5 ) Setting the Random Seeds

# %%
np.random.seed(42)
rn.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# <a id="content3"></a>
# ## 3 ) Modelling

# %% [markdown]
# ## 3.1 ) Building the ConvNet Model

# %%
# # modelling starts using a CNN.

model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',activation ='relu', input_shape = (150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))


model.add(Conv2D(filters =96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(5, activation = "softmax"))

# %% [markdown]
# ## 3.2 ) Using a LR Annealer

# %%
batch_size=128
epochs=50

from keras.callbacks import ReduceLROnPlateau
red_lr= ReduceLROnPlateau(monitor='val_acc',patience=3,verbose=1,factor=0.1)

# %% [markdown]
# ## 3.3 ) Data Augmentation to prevent Overfitting

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)

# %% [markdown]
# ## 3.4 ) Compiling the Keras Model & Summary

# %%
model.compile(optimizer=Adam(learning_rate=0.001),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 150, 150, 32)        │           2,432 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 75, 75, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 75, 75, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 37, 37, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 37, 37, 96)          │          55,392 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 18, 18, 96)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 18, 18, 96)          │          83,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 9, 9, 96)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 7776)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       3,981,824 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 5)                   │           2,565 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,143,749 (15.81 MB)
#  Trainable params: 4,143,749 (15.81 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 3.5 ) Fitting on the Training set and making predcitons on the Validation set

# %%
History = model.fit(datagen.flow(x_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test,y_test),
                              verbose = 1, steps_per_epoch=x_train.shape[0] // batch_size)
# model.fit(x_train,y_train,epochs=epochs,batch_size=batch_size,validation_data = (x_test,y_test))
# Out:
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 32s 880ms/step - accuracy: 0.3087 - loss: 1.5148 - val_accuracy: 0.5037 - val_loss: 1.1827
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5625 - loss: 1.0818 - val_accuracy: 0.4898 - val_loss: 1.2103
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 27s 655ms/step - accuracy: 0.4942 - loss: 1.2030 - val_accuracy: 0.4796 - val_loss: 1.2281
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5391 - loss: 1.1337 - val_accuracy: 0.5083 - val_loss: 1.1877
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 659ms/step - accuracy: 0.5435 - loss: 1.1307 - val_accuracy: 0.5472 - val_loss: 1.0953
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.6094 - loss: 0.9756 - val_accuracy: 0.5833 - val_loss: 1.0196
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 662ms/step - accuracy: 0.6022 - loss: 0.9765 - val_accuracy: 0.6269 - val_loss: 0.9352
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6641 - loss: 0.9221 - val_accuracy: 0.6120 - val_loss: 0.9859
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 677ms/step - accuracy: 0.6264 - loss: 0.9478 - val_accuracy: 0.6093 - val_loss: 0.9608
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7266 - loss: 0.7738 - val_accuracy: 0.6009 - val_loss: 1.0286
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 666ms/step - accuracy: 0.6191 - loss: 0.9623 - val_accuracy: 0.6315 - val_loss: 0.9651
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6797 - loss: 1.0246 - val_accuracy: 0.6509 - val_loss: 0.8801
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 686ms/step - accuracy: 0.6624 - loss: 0.8604 - val_accuracy: 0.6519 - val_loss: 0.8969
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7266 - loss: 0.7816 - val_accuracy: 0.6352 - val_loss: 0.9941
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 16s 646ms/step - accuracy: 0.6673 - loss: 0.8690 - val_accuracy: 0.6556 - val_loss: 0.9743
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6719 - loss: 0.8415 - val_accuracy: 0.6657 - val_loss: 0.8850
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 667ms/step - accuracy: 0.6971 - loss: 0.7871 - val_accuracy: 0.6769 - val_loss: 0.8115
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7656 - loss: 0.7382 - val_accuracy: 0.6870 - val_loss: 0.8118
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 654ms/step - accuracy: 0.6944 - loss: 0.8024 - val_accuracy: 0.6870 - val_loss: 0.8332
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.7266 - loss: 0.7479 - val_accuracy: 0.6815 - val_loss: 0.8327
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 661ms/step - accuracy: 0.7158 - loss: 0.7460 - val_accuracy: 0.6917 - val_loss: 0.8042
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7568 - loss: 0.6317 - val_accuracy: 0.6954 - val_loss: 0.7862
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 681ms/step - accuracy: 0.7094 - loss: 0.7563 - val_accuracy: 0.6991 - val_loss: 0.8492
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6562 - loss: 0.9014 - val_accuracy: 0.6870 - val_loss: 0.8411
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 664ms/step - accuracy: 0.7321 - loss: 0.6977 - val_accuracy: 0.7111 - val_loss: 0.7649
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7734 - loss: 0.7189 - val_accuracy: 0.7130 - val_loss: 0.7602
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 690ms/step - accuracy: 0.7317 - loss: 0.7023 - val_accuracy: 0.7241 - val_loss: 0.7783
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7344 - loss: 0.6317 - val_accuracy: 0.7315 - val_loss: 0.7673
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 16s 643ms/step - accuracy: 0.7553 - loss: 0.6510 - val_accuracy: 0.7074 - val_loss: 0.8056
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.7656 - loss: 0.7286 - val_accuracy: 0.7259 - val_loss: 0.7514
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 675ms/step - accuracy: 0.7549 - loss: 0.6230 - val_accuracy: 0.7259 - val_loss: 0.7476
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7344 - loss: 0.7051 - val_accuracy: 0.7185 - val_loss: 0.7669
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 16s 651ms/step - accuracy: 0.7541 - loss: 0.6422 - val_accuracy: 0.7111 - val_loss: 0.7967
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.7031 - loss: 0.8048 - val_accuracy: 0.7139 - val_loss: 0.8047
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 684ms/step - accuracy: 0.7577 - loss: 0.6036 - val_accuracy: 0.7278 - val_loss: 0.7151
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8108 - loss: 0.4992 - val_accuracy: 0.7407 - val_loss: 0.7079
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 16s 652ms/step - accuracy: 0.7705 - loss: 0.6182 - val_accuracy: 0.7481 - val_loss: 0.6812
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8359 - loss: 0.4867 - val_accuracy: 0.7435 - val_loss: 0.6850
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 648ms/step - accuracy: 0.7751 - loss: 0.5889 - val_accuracy: 0.7333 - val_loss: 0.7316
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7031 - loss: 0.6843 - val_accuracy: 0.7537 - val_loss: 0.6880
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 644ms/step - accuracy: 0.7751 - loss: 0.5753 - val_accuracy: 0.7481 - val_loss: 0.6985
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7812 - loss: 0.5589 - val_accuracy: 0.7333 - val_loss: 0.7254
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 672ms/step - accuracy: 0.7882 - loss: 0.5582 - val_accuracy: 0.7574 - val_loss: 0.6834
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.7422 - loss: 0.5717 - val_accuracy: 0.7583 - val_loss: 0.6472
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 16s 656ms/step - accuracy: 0.7925 - loss: 0.5485 - val_accuracy: 0.7389 - val_loss: 0.7706
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.7812 - loss: 0.5288 - val_accuracy: 0.7398 - val_loss: 0.7600
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 16s 648ms/step - accuracy: 0.7990 - loss: 0.5479 - val_accuracy: 0.7565 - val_loss: 0.6691
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7734 - loss: 0.6281 - val_accuracy: 0.7565 - val_loss: 0.6724
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 667ms/step - accuracy: 0.7944 - loss: 0.5443 - val_accuracy: 0.7519 - val_loss: 0.6974
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7969 - loss: 0.5368 - val_accuracy: 0.7574 - val_loss: 0.6910

# %% [markdown]
# <a id="content4"></a>
# ## 4 ) Evaluating the Model Performance

# %%
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
plt.plot(History.history['accuracy'])
plt.plot(History.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %% [markdown]
# <a id="content5"></a>
# ## 5 ) Visualizing Predictons on the Validation Set

# %%
# getting predictions on val set.
pred=model.predict(x_test)
pred_digits=np.argmax(pred,axis=1)
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step

# %%
# now storing some properly as well as misclassified indexes'.
i=0
prop_class=[]
mis_class=[]

for i in range(len(y_test)):
    if(np.argmax(y_test[i])==pred_digits[i]):
        prop_class.append(i)
    if(len(prop_class)==8):
        break

i=0
for i in range(len(y_test)):
    if(not np.argmax(y_test[i])==pred_digits[i]):
        mis_class.append(i)
    if(len(mis_class)==8):
        break

# %% [markdown]
# #### CORRECTLY CLASSIFIED FLOWER IMAGES

# %%
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# Assuming le is your LabelEncoder, prop_class is your list of indices, pred_digits is your list of predicted labels, and y_test is your test labels
count = 0
fig, ax = plt.subplots(2, 2, figsize=(10, 10))

for i in range(2):
    for j in range(2):
        ax[i, j].imshow(x_test[prop_class[count]])
        predicted_flower = le.inverse_transform([pred_digits[prop_class[count]]])[0]  # Ensure this is a single value
        actual_flower = le.inverse_transform([np.argmax(y_test[prop_class[count]])])[0]  # Ensure this is a single value
        ax[i, j].set_title(f"Predicted Flower: {predicted_flower}\nActual Flower: {actual_flower}")
        plt.tight_layout()
        count += 1

plt.show()

# %% [markdown]
# #### MISCLASSIFIED IMAGES OF FLOWERS

# %%
# Assuming le is your LabelEncoder, mis_class is your list of misclassified indices, pred_digits is your list of predicted labels, and y_test is your test labels
count = 0
fig, ax = plt.subplots(2, 2, figsize=(10, 10))

for i in range(2):
    for j in range(2):
        ax[i, j].imshow(x_test[mis_class[count]])
        predicted_flower = le.inverse_transform([pred_digits[mis_class[count]]])[0]  # Ensure this is a single value
        actual_flower = le.inverse_transform([np.argmax(y_test[mis_class[count]])])[0]  # Ensure this is a single value
        ax[i, j].set_title(f"Predicted Flower: {predicted_flower}\nActual Flower: {actual_flower}")
        plt.tight_layout()
        count += 1

plt.show()

# %%
import datetime, pytz;
print("Current Time in IST:", datetime.datetime.now(pytz.utc).astimezone(pytz.timezone('Asia/Kolkata')).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Current Time in IST: 2025-02-12 23:23:16

# %% [markdown]
# #  THE END.
